# %%
import os
import platform
from modules.path_utils import PathUtils as p_utils

#########################################################################################################################################################
# PARAMETROS DEFINIDOS EN FUNCION DEL USUARIO
#########################################################################################################################################################

# SI VAMOS A USAR UN DATASET
USE_DATASET = True

# Ruta relativa hacia el fichero CSV del dataset
dataset_dir_relative = '../DATASETs/emptyNonEmptyDataset/'

csv_file_relative = './data/700Train.csv'

# Ruta relativa hacia carpeta de imagenes de entrada
images_dir_relative = './input'

# Ruta relativa hacia la librería ai4eutils
ai4eutils_relative = "./repos/ai4eutils"

# Ruta relativa hacia la librería CameraTraps
CameraTraps_relative = "./repos/CameraTraps"

# Ruta relativa hacia la carpeta destino de los ficheros JSON:
output_json_path_relative = ('./output_json')

# Ruta relativa al modelo de detección
model_relative = './models/megadetector_v4_1_0.pb'

#########################################################################################################################################################
#########################################################################################################################################################

home = os.path.expanduser("~")

ai4utils = os.path.abspath(ai4eutils_relative)
CameraTraps = os.path.abspath(CameraTraps_relative)
csv_file = os.path.abspath(csv_file_relative)
dataset_dir = os.path.abspath(dataset_dir_relative)
images_dir = os.path.abspath(images_dir_relative)
output_json = os.path.abspath(output_json_path_relative)
model = os.path.abspath(model_relative)

try:
    os.environ['PYTHONPATH']
except KeyError:
    os.environ['PYTHONPATH'] = ""
if platform.system() == 'Windows':
    os.environ['PYTHONPATH'] += (";" + ai4utils)
    os.environ['PYTHONPATH'] += (";" + CameraTraps)
else:
    os.environ['PYTHONPATH'] += (":" + ai4utils)
    os.environ['PYTHONPATH'] += (":" + CameraTraps)

print('=======================================================================================================================================')
print('PYTHONPATH: ' + os.environ['PYTHONPATH'])
print('')
print('ai4eutils PATH: ' + '\t' + ai4utils)
print('CameraTraps PATH: ' + '\t' + CameraTraps)
print('CSV PATH: ' + '\t' + '\t' + csv_file)
print('dataset PATH: ' + '\t' + '\t' + dataset_dir)
print('imagenes PATH: ' + '\t' + '\t' + images_dir)
print('output_json PATH: ' + '\t' + output_json)
print('modelo: ' + '\t' + '\t' + model)
print('=======================================================================================================================================')
# Out:
# =======================================================================================================================================
# PYTHONPATH: /Users/carlos/.vscode/extensions/ms-toolsai.jupyter-2022.6.1201981810/pythonFiles:/Users/carlos/.vscode/extensions/ms-toolsai.jupyter-2022.6.1201981810/pythonFiles/lib/python:/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/ai4eutils:/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/CameraTraps
#
# ai4eutils PATH: 	/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/ai4eutils
# CameraTraps PATH: 	/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/CameraTraps
# CSV PATH: 		/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/data/700Train.csv
# dataset PATH: 		/Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset
# imagenes PATH: 		/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input
# output_json PATH: 	/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/output_json
# modelo: 		/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/models/megadetector_v4_1_0.pb
# =======================================================================================================================================

# %%
if USE_DATASET:
    # !python ./modules/genera_detecciones.py "$model" --dataset_dir "$dataset_dir" --csv_file "$csv_file" --output_dir "$output_json"
else:
    # !python ./modules/genera_detecciones.py "$model" --image_dir "$images_dir" --output_dir "$output_json"
# Out:
# ==========================================================================================
# TensorFlow version: 2.9.2
# Is GPU available? tf.test.is_gpu_available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ==========================================================================================
#
# Ejecutando detector en 1450 imágenes...
#
# ==========================================================================================
# TFDetector: Cargando gráficos
# TFDetector: Gráficos de detección, cargados.
# ==========================================================================================
#
# Metal device set to: Apple M1
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# 2022-07-25 18:59:06.808539: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-07-25 18:59:06.808862: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
#
# Modelo cargado en: 4.63 seconds.
# ==========================================================================================
#
#   0%|                                                  | 0/1450 [00:00<?, ?it/s]
# 2022-07-25 18:59:07.177504: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# 2022-07-25 18:59:07.354087: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-07-25 18:59:07.359675: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-25 18:59:09.000542: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -1047 } dim { size: -1048 } dim { size: -1049 } dim { size: 1088 } } } inputs { dtype: DT_FLOAT shape { dim { size: -108 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -108 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 17 } } device { type: "CPU" model: "0" num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -108 } dim { size: 17 } dim { size: 17 } dim { size: 1088 } } }
#
# Generadas detecciones de imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vaca/cow_CaltechCameraTrap/5903cd72-23d2-11e8-a6a3-ec086b02610b.jpg en 14.2 seconds.
#   0%|                                        | 1/1450 [00:14<5:43:17, 14.22s/it]
#
# Generadas detecciones de imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/cervidae/CERVIDREDORFALLOWDEER_ZOO_5_6_7_9/5_20210219 (134) (2021_04_15 06_16_22 UTC).JPG en 5.01 seconds.
#   0%|                                        | 2/1450 [00:19<3:32:26,  8.80s/it]
#
# Generadas detecciones de imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/NOANIMAL_ZOO_1_4/34_20210115 (6771).JPG en 3.92 seconds.
#   0%|                                        | 3/1450 [00:23<2:38:36,  6.58s/it]
#
# Generadas detecciones de imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/gato_domestico/cat_IslandConservationCameraTraps/puertorico_20_20150513_013502_img_0473.jpg en 3.85 seconds.
#   0%|                                        | 4/1450 [00:27<2:12:35,  5.50s/it]
#
# Generadas detecciones de imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/NOANIMAL_ZOO_5_6_7_9/24_20210418 (18343).JPG en 3.65 seconds.
#   0%|▏                                       | 5/1450 [00:30<1:56:29,  4.84s/it]
#
# Generadas detecciones de imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/leporido/rabbit_IslandConservationCameraTraps/chile_frances012013_1401201374758.jpg en 4.65 seconds.
#   0%|▏                                       | 6/1450 [00:35<1:54:58,  4.78s/it]
#
# Generadas detecciones de imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/micromamiferos/micromamiferos_Paco_Carro_JC/IMG_0210.JPG en 3.96 seconds.
#   0%|▏                                       | 7/1450 [00:39<1:48:29,  4.51s/it]
#
# Generadas detecciones de imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/cervidae/CERVIDREDORFALLOWDEER_ZOO_5_6_7_9/18_20210219 (7448) (2021_04_15 06_16_22 UTC).JPG en 3.94 seconds.
#   1%|▏                                       | 8/1450 [00:43<1:44:04,  4.33s/it]
#
# Generadas detecciones de imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vaca/cow_CaltechCameraTrap/58b4aba6-23d2-11e8-a6a3-ec086b02610b.jpg en 3.77 seconds.
#   1%|▏                                       | 9/1450 [00:47<1:39:50,  4.16s/it]
#
# Generadas detecciones de imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/jabali/WILDBOAR_ZOO_1_4/37_20201116 (10737).JPG en 4.14 seconds.
#   1%|▎                                      | 10/1450 [00:51<1:39:41,  4.15s/it]
#
# Generadas detecciones de imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/caballo/HORSE_ZOO_1_4/2_20210115 (2835).JPG en 4.12 seconds.
#   1%|▎                                      | 11/1450 [00:55<1:39:25,  4.15s/it]
#
# Generadas detecciones de imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/cervidae/CERVIDREDORFALLOWDEER_ZOO_5_6_7_9/28_20210615 (233).JPG en 4.01 seconds.
#   1%|▎                                      | 12/1450 [00:59<1:38:23,  4.11s/it]
#
# Generadas detecciones de imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/cervidae/CERVIDREDORFALLOWDEER_ZOO_5_6_7_9