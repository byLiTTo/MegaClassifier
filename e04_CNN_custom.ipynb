# %% [markdown]
# # DEFINICIÓN DE PARÁMETROS

# %%
#######################################################################################################################

# Ruta hacia los CSV del dataset
train_file_relative = '../local/custom_dataset/train'
validation_file_relative = '../local/custom_dataset/validation'
test_file_relative = '../local/custom_dataset/test'

# Ruta al directorio de imágenes con máscara aplicada
masked_dir_relative = '../local/output_masked'
edited_dir_relative = '../local/output_edited'

model_dir_relative = "./models"

# Ruta relativa hacia la librería ai4eutils
ai4eutils_relative = "./repos/ai4eutils"

# Ruta relativa hacia la librería CameraTraps
CameraTraps_relative = "./repos/CameraTraps"

#######################################################################################################################

# %% [markdown]
# # DEFINICIÓN PARÁMETROS CNN

# %%
#######################################################################################################################

EPOCHS = 50
LEARNING_RATE = 1e-4
BATCH_SIZE = 16

IMG_HEIGHT = IMG_WIDTH = 448

#######################################################################################################################

# %%
import os
import platform

import tensorflow as tf
from matplotlib import pyplot as plt
from tensorflow import keras

home = os.path.expanduser("~")

ai4utils = os.path.abspath(ai4eutils_relative)
CameraTraps = os.path.abspath(CameraTraps_relative)
train_file = os.path.abspath(train_file_relative)
validation_file = os.path.abspath(validation_file_relative)
test_file = os.path.abspath(test_file_relative)
masked_dir = os.path.abspath(masked_dir_relative)
edited_dir = os.path.abspath(edited_dir_relative)
model_dir = os.path.abspath(model_dir_relative)

try:
    os.environ['PYTHONPATH']
except KeyError:
    os.environ['PYTHONPATH'] = ""
if platform.system() == 'Windows':
    os.environ['PYTHONPATH'] += (";" + ai4utils)
    os.environ['PYTHONPATH'] += (";" + CameraTraps)
else:
    os.environ['PYTHONPATH'] += (":" + ai4utils)
    os.environ['PYTHONPATH'] += (":" + CameraTraps)

print('==============================================================================================================')
print('PYTHONPATH: ' + os.environ['PYTHONPATH'])
print('')
print('ai4eutils PATH: ' + '\t\t' + ai4utils)
print('CameraTraps PATH: ' + '\t\t' + CameraTraps)
print('Train CSV PATH: ' + '\t\t' + train_file)
print('Validation CSV PATH: ' + '\t' + validation_file)
print('Test CSV PATH: ' + '\t\t\t' + test_file)
print('masked PATH: ' + '\t\t\t' + masked_dir)
print('edited PATH: ' + '\t\t\t' + edited_dir)
print('models PATH: ' + '\t\t\t' + model_dir)
print('==============================================================================================================')
# Out:
# ==============================================================================================================
# PYTHONPATH: /Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo:/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/ai4eutils:/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/CameraTraps
#
# ai4eutils PATH: 		/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/ai4eutils
# CameraTraps PATH: 		/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/CameraTraps
# Train CSV PATH: 		/Users/carlos/WORKSPACE/local/custom_dataset/train
# Validation CSV PATH: 	/Users/carlos/WORKSPACE/local/custom_dataset/validation
# Test CSV PATH: 			/Users/carlos/WORKSPACE/local/custom_dataset/test
# masked PATH: 			/Users/carlos/WORKSPACE/local/output_masked
# edited PATH: 			/Users/carlos/WORKSPACE/local/output_edited
# models PATH: 			/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/models
# ==============================================================================================================

# %% [markdown]
# # Generate Datasets

# %%
custom = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1. / 255,
    horizontal_flip=True,
)

general = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1. / 255)

train_dataset = custom.flow_from_directory(
    train_file,
    class_mode='binary',
    shuffle=True,
    batch_size=BATCH_SIZE,
    target_size=(IMG_HEIGHT, IMG_WIDTH)
)

validation_dataset = general.flow_from_directory(
    validation_file,
    class_mode='binary',
    shuffle=True,
    batch_size=BATCH_SIZE,
    target_size=(IMG_HEIGHT, IMG_WIDTH)
)

test_dataset = general.flow_from_directory(
    test_file,
    class_mode='binary',
    shuffle=True,
    batch_size=BATCH_SIZE,
    target_size=(IMG_HEIGHT, IMG_WIDTH)
)
# Out:
# Found 1445 images belonging to 2 classes.
# Found 312 images belonging to 2 classes.
# Found 311 images belonging to 2 classes.

# %% [markdown]
# # Custom CNN Architecture

# %%
model = keras.Sequential([
    keras.layers.Conv2D(16, kernel_size=3, padding='same', activation=tf.nn.relu,
                        input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
    keras.layers.MaxPooling2D(2, 2),

    keras.layers.Conv2D(32, kernel_size=3, padding='same', activation=tf.nn.relu),
    keras.layers.MaxPooling2D(2, 2),

    keras.layers.Conv2D(64, kernel_size=3, padding='same', activation=tf.nn.relu),
    keras.layers.MaxPooling2D(2, 2),

    keras.layers.Conv2D(32, kernel_size=3, padding='same', activation=tf.nn.relu),
    keras.layers.MaxPooling2D(2, 2),

    keras.layers.Conv2D(16, kernel_size=3, padding='same', activation=tf.nn.relu),
    keras.layers.MaxPooling2D(2, 2),

    # Full connected
    keras.layers.Flatten(),
    keras.layers.Dense(1024, kernel_regularizer=keras.regularizers.l2(LEARNING_RATE), activation=tf.nn.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1024, kernel_regularizer=keras.regularizers.l2(LEARNING_RATE), activation=tf.nn.relu),
    keras.layers.Dropout(0.5),

    # Capa de salida
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=[keras.losses.BinaryCrossentropy()],
    metrics=['accuracy'])
# Out:
# Metal device set to: Apple M1
# 2022-10-18 10:23:27.451783: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-10-18 10:23:27.451916: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
hist = model.fit(
    train_dataset,
    steps_per_epoch=train_dataset.samples // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=validation_dataset,
    validation_steps=validation_dataset.samples // BATCH_SIZE,
    verbose=1
)
results = model.evaluate(
    test_dataset,
    batch_size=BATCH_SIZE,
    verbose=1
)

fig = plt.figure(figsize=(15, 12))
fig.suptitle('Custom Architecture using edited images')

ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

ax1.plot(hist.history['loss'], color='blue', label='train loss', )
ax1.plot(hist.history['val_loss'], color='green', label='validation loss')
ax1.legend(loc="upper right")
ax2.plot(hist.history['accuracy'], color='orange', label='train accuracy')
ax2.plot(hist.history['val_accuracy'], color='red', label='validation accuracy')
ax2.legend(loc="lower right")
plt.show()
# Out:
# Epoch 1/50
# 2022-10-18 10:23:27.754862: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-10-18 10:23:28.077623: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 90/90 [==============================] - ETA: 0s - loss: 0.7460 - accuracy: 0.8146
# 2022-10-18 10:23:45.801679: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 90/90 [==============================] - 20s 215ms/step - loss: 0.7460 - accuracy: 0.8146 - val_loss: 0.6704 - val_accuracy: 0.9112
# Epoch 2/50
# 90/90 [==============================] - 19s 208ms/step - loss: 0.6777 - accuracy: 0.8978 - val_loss: 0.6283 - val_accuracy: 0.9112
# Epoch 3/50
# 90/90 [==============================] - 19s 206ms/step - loss: 0.5857 - accuracy: 0.8859 - val_loss: 0.4854 - val_accuracy: 0.9112
# Epoch 4/50
# 90/90 [==============================] - 19s 209ms/step - loss: 0.4991 - accuracy: 0.8950 - val_loss: 0.4494 - val_accuracy: 0.9178
# Epoch 5/50
# 90/90 [==============================] - 19s 205ms/step - loss: 0.4779 - accuracy: 0.8985 - val_loss: 0.4499 - val_accuracy: 0.9079
# Epoch 6/50
# 90/90 [==============================] - 18s 204ms/step - loss: 0.4637 - accuracy: 0.8964 - val_loss: 0.4253 - val_accuracy: 0.9178
# Epoch 7/50
# 90/90 [==============================] - 18s 204ms/step - loss: 0.4451 - accuracy: 0.8992 - val_loss: 0.4207 - val_accuracy: 0.9145
# Epoch 8/50
# 90/90 [==============================] - 18s 204ms/step - loss: 0.4229 - accuracy: 0.9006 - val_loss: 0.4234 - val_accuracy: 0.9145
# Epoch 9/50
# 90/90 [==============================] - 18s 204ms/step - loss: 0.4203 - accuracy: 0.9041 - val_loss: 0.4000 - val_accuracy: 0.9145
# Epoch 10/50
# 90/90 [==============================] - 19s 207ms/step - loss: 0.3996 - accuracy: 0.9034 - val_loss: 0.3869 - val_accuracy: 0.9145
# Epoch 11/50
# 90/90 [==============================] - 19s 205ms/step - loss: 0.3849 - accuracy: 0.9027 - val_loss: 0.3775 - val_accuracy: 0.9178
# Epoch 12/50
# 90/90 [==============================] - 18s 204ms/step - loss: 0.3893 - accuracy: 0.9006 - val_loss: 0.3821 - val_accuracy: 0.9145
# Epoch 13/50
# 90/90 [==============================] - 18s 204ms/step - loss: 0.3626 - accuracy: 0.9076 - val_loss: 0.3672 - val_accuracy: 0.9145
# Epoch 14/50
# 90/90 [==============================] - 18s 205ms/step - loss: 0.3595 - accuracy: 0.9083 - val_loss: 0.3424 - val_accuracy: 0.9243
# Epoch 15/50
# 90/90 [==============================] - 19s 205ms/step - loss: 0.3555 - accuracy: 0.9132 - val_loss: 0.3530 - val_accuracy: 0.9243
# Epoch 16/50
# 90/90 [==============================] - 18s 204ms/step - loss: 0.3435 - accuracy: 0.9153 - val_loss: 0.3864 - val_accuracy: 0.9079
# Epoch 17/50
# 90/90 [==============================] - 18s 204ms/step - loss: 0.3169 - accuracy: 0.9258 - val_loss: 0.3565 - val_accuracy: 0.9211
# Epoch 18/50
# 90/90 [==============================] - 19s 206ms/step - loss: 0.3093 - accuracy: 0.9237 - val_loss: 0.3477 - val_accuracy: 0.9211
# Epoch 19/50
# 90/90 [==============================] - 18s 204ms/step - loss: 0.3025 - accuracy: 0.9279 - val_loss: 0.3617 - val_accuracy: 0.9178
# Epoch 20/50
# 90/90 [==============================] - 19s 205ms/step - loss: 0.2963 - accuracy: 0.9314 - val_loss: 0.3614 - val_accuracy: 0.9211
# Epoch 21/50
# 90/90 [==============================] - 18s 205ms/step - loss: 0.2762 - accuracy: 0.9377 - val_loss: 0.3570 - val_accuracy: 0.9243
# Epoch 22/50
# 90/90 [==============================] - 19s 205ms/step - loss: 0.2749 - accuracy: 0.9363 - val_loss: 0.3539 - val_accuracy: 0.9178
# Epoch 23/50
# 90/90 [==============================] - 19s 205ms/step - loss: 0.2584 - accuracy: 0.9391 - val_loss: 0.3358 - val_accuracy: 0.9309
# Epoch 24/50
# 90/90 [==============================] - 19s 205ms/step - loss: 0.2569 - accuracy: 0.9433 - val_loss: 0.3671 - val_accuracy: 0.9145
# Epoch 25/50
# 90/90 [==============================] - 18s 205ms/step - loss: 0.2520 - accuracy: 0.9391 - val_loss: 0.3556 - val_accuracy: 0.9178
# Epoch 26/50
# 90/90 [==============================] - 19s 205ms/step - loss: 0.2459 - accuracy: 0.9475 - val_loss: 0.3757 - val_accuracy: 0.9243
# Epoch 27/50
# 90/90 [==============================] - 18s 204ms/step - loss: 0.2197 - accuracy: 0.9559 - val_loss: 0.3545 - val_accuracy: 0.9211
# Epoch 28/50
# 90/90 [==============================] - 19s 205ms/step - loss: 0.2056 - accuracy: 0.9629 - val_loss: 0.4048 - val_accuracy: 0.9013
# Epoch 29/50
# 90/90 [==============================] - 18s 205ms/step - loss: 0.2005 - accuracy: 0.9622 - val_loss: 0.4023 - val_accuracy: 0.9079
# Epoch 30/50
# 90/90 [==============================] - 18s 204ms/step - loss: 0.2191 - accuracy: 0.9545 - val_loss: 0.4044 - val_accuracy: 0.8980
# Epoch 31/50
# 90/90 [==============================] - 18s 205ms/step - loss: 0.2087 - accuracy: 0.9587 - val_loss: 0.4578 - val_accuracy: 0.8651
# Epoch 32/50
# 90/90 [==============================] - 18s 205ms/step - loss: 0.1948 - accuracy: 0.9636 - val_loss: 0.4178 - val_accuracy: 0.8914
# Epoch 33/50
# 90/90 [==============================] - 18s 204ms/step - loss: 0.1747 - accuracy: 0.9741 - val_loss: 0.4267 - val_accuracy: 0.9309
# Epoch 34/50
# 90/90 [==============================] - 18s 204ms/step - loss: 0.1744 - accuracy: 0.9720 - val_loss: 0.3897 - val_accuracy: 0.9178
# Epoch 35/50
# 90/90 [==============================] - 18s 204ms/step - loss: 0.1688 - accuracy: 0.9720 - val_loss: 0.4625 - val_accuracy: 0.8651
# Epoch 36/50
# 90/90 [==============================] - 18s 204ms/step - loss: 0.1590 - accuracy: 0.9790 - val_loss: 0.4328 - val_accuracy: 0.9309
# Epoch 37/50
# 90/90 [==============================] - 19s 205ms/step - loss: 0.1594 - accuracy: 0.9762 - val_loss: 0.5281 - val_accuracy: 0.9342
# Epoch 38/50
# 90/90 [==============================] - 18s 203ms/step - loss: 0.1565 - accuracy: 0.9748 - val_loss: 0.4518 - val_accuracy: 0.9112
# Epoch 39/50
# 90/90 [==============================] - 18s 202ms/step - loss: 0.1515 - accuracy: 0.9783 - val_loss: 0.4710 - val_accuracy: 0.9112
# Epoch 40/50
# 90/90 [==============================] - 19s 207ms/step - loss: 0.1407 - accuracy: 0.9860 - val_loss: 0.4759 - val_accuracy: 0.8914
# Epoch 41/50
# 90/90 [==============================] - 18s 204ms/step - loss: 0.1385 - accuracy: 0.9832 - val_loss: 0.5753 - val_accuracy: 0.8947
# Epoch 42/50
# 90/90 [==============================] - 19s 206ms/step - loss: 0.1409 - accuracy: 0.9811 - val_loss: 0.5277 - val_accuracy: 0.9178
# Epoch 43/50
# 90/90 [==============================] - 19s 206ms/step - loss: 0.1394 - accuracy: 0.9811 - val_loss: 0.6609 - val_accuracy: 0.9178
# Epoch 44/50
# 90/90 [==============================] - 18s 202ms/step - loss: 0.1701 - accuracy: 0.9727 - val_loss: 0.4821 - val_accuracy: 0.8980
# Epoch 45/50
# 90/90 [==============================] - 18s 202ms/step - loss: 0.1337 - accuracy: 0.9825 - val_loss: 0.4871 - val_accuracy: 0.9046
# Epoch 46/50
# 90/90 [==============================] - 18s 203ms/step - loss: 0.1287 - accuracy: 0.9867 - val_loss: 0.5314 - val_accuracy: 0.9178
# Epoch 47/50
# 90/90 [==============================] - 18s 203ms/step - loss: 0.1251 - accuracy: 0.9867 - val_loss: 0.5326 - val_accuracy: 0.9211
# Epoch 48/50
# 90/90 [==============================] - 18s 203ms/step - loss: 0.1157 - accuracy: 0.9881 - val_loss: 0.6218 - val_accuracy: 0.9178
# Epoch 49/50
# 90/90 [==============================] - 18s 202ms/step - loss: 0.1253 - accuracy: 0.9839 - val_loss: 0.5189 - val_accuracy: 0.8914
# Epoch 50/50
# 90/90 [==============================] - 18s 202ms/step - loss: 0.1141 - accuracy: 0.9909 - val_loss: 0.5917 - val_accuracy: 0.9013
# 20/20 [==============================] - 2s 80ms/step - loss: 0.4578 - accuracy: 0.9035
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [6], in <cell line: 24>()
#      22 ax1.plot(hist.history['val_loss'], color='green', label='validation loss')
#      23 ax1.legend(loc="upper right")
# ---> 24 ax2.plot(hist.history['train accuracy'], color='orange', label='train accuracy')
#      25 ax2.plot(hist.history['val_accuracy'], color='red', label='validation accuracy')
#      26 ax2.legend(loc="lower right")
#
# KeyError: 'train accuracy'

# %%
fig = plt.figure(figsize=(15, 12))
fig.suptitle('Custom Architecture using edited images')

ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

ax1.plot(hist.history['loss'], color='blue', label='train loss', )
ax1.plot(hist.history['val_loss'], color='green', label='validation loss')
ax1.legend(loc="upper right")
ax2.plot(hist.history['accuracy'], color='orange', label='train accuracy')
ax2.plot(hist.history['val_accuracy'], color='red', label='validation accuracy')
ax2.legend(loc="lower right")
plt.show()
