# %%
import os
import src.data.Dataset as dt

dataset_file = os.path.abspath("./data/raw/20Images_binary.csv")
dataset = dt.load_from_csv(dataset_file)
dataset
# Out:
# The file /Users/carlos/WORKSPACE/MegaClassifier/data/raw/20Images_binary.csv has been successfully opened.
#                                             file_name  label
# 0   \vacia\empty_IslandConservationCameraTraps\dom...      0
# 1       \vacia\NOANIMAL_ZOO_1_4\28_20201019 (329).JPG      0
# 2   \jabali\jabali_PNM_2013-O_ISAAC\f27560IMAG0113...      1
# 3     \jabali\WILDBOAR_ZOO_1_4\37_20210115 (2245).JPG      1
# 4   \vacia\NOANIMAL_ZOO_5_6_7_9\50_20210408 (6876)...      0
# 5      \lince\Lince_a_Linces2_Leo_JC\Lince58 (22).JPG      1
# 6     \leporido\conejo_Paco_Carro_JC\PICT0646 (2).JPG      1
# 7   \zorro\zorro_Leo_Otra_fauna_PASADA_POR_LA_RED_...      1
# 8   \vacia\empty_IslandConservationCameraTraps\dom...      0
# 9   \cervidae\CERVIDREDORFALLOWDEER_ZOO_1_4\34_202...      1
# 10  \micromamiferos\rat_IslandConservationCameraTr...      1
# 11     \jabali\WILDBOAR_ZOO_1_4\22_20210115 (801).JPG      1
# 12    \jabali\WILDBOAR_ZOO_5_6_7_9\1_20210319 (7).JPG      1
# 13  \vacia\empty_SnapshotMountainZebra\MTZ_S1_D05_...      0
# 14  \humanovehiculo\humano_vehiculo_PNM_2013-O_ISA...      1
# 15      \vacia\vacia_javi_2_JC\27_20201023 (4595).JPG      0
# 16  \vacia\SnampshotEnonkishu\ENO_S1_D06_R1_IMAG52...      0
# 17  \vacia\empty_SnapshotMountainZebra\MTZ_S1_D06_...      0
# 18              \vaca\vaca_Paco_Carro_JC\PICT0042.JPG      1
# 19  \vacia\empty_SnapshotMountainZebra\MTZ_S1_C06_...      0
# 20      \caballo\HORSE_ZOO_1_4\15_20201117 (7287).JPG      1
# 21   \vacia\vacias_PNM_2013-O_ISAAC\f7213IMAG0066.JPG      0
# 22         \tejon\Tejon_PEPE_IREC_JC\IMAG0423_(5).JPG      1
# 23  \ave\bird_CaltechCameraTrap\5976a214-23d2-11e8...      1
# 24  \cervidae\2_Ciervo_Paco_Carro_camarasliron_4_2...      1
# 25       \vaca\COW_ZOO_5_6_7_9\21_20210418 (1498).JPG      1
# 26  \vacia\empty_IslandConservationCameraTraps\ecu...      0
# 27  \cervidae\CERVIDREDORFALLOWDEER_ZOO_1_4\20_202...      1
# 28     \vacia\NOANIMAL_ZOO_1_4\34_20210115 (1643).JPG      0
# 29  \cervidae\CERVIDREDORFALLOWDEER_ZOO_5_6_7_9\20...      1
# 30  \jabali\jabali_Paco_Carro_camarasliron_4_2_PAS...      1
# 31  \vacia\NOANIMAL_ZOO_5_6_7_9\20_20210618 (3959)...      0
# 32     \leporido\Conejo_PNC_2014_JC\c8663IM000121.JPG      1
# 33  \garduna\Garduna_PNM_2013-0_ME\f14844IM000051.JPG      1
# 34     \vacia\vacia_alumno_AM_2\25_20201024 (312).JPG      0
# 35   \lince\Lince_a_Linces2_Leo_JC\lince130 (306).JPG      1
# 36  \cervidae\CERVIDREDORFALLOWDEER_ZOO_5_6_7_9\10...      1
# 37    \cervidae\Ciervo_PNC_2012_JC\a34265IM000500.JPG      1
# 38   \cervidae\ciervo_simone_2\37_20201024 (1156).JPG      1
# 39  \cervidae\2_ciervo_alumno_2_TH\34_20201024 (23...      1
# 40   \cervidae\ciervo_simone_2\34_20201024 (5494).JPG      1
# 41  \vacia\vacia_alumno_2_2_TH_JC\27_20201023 (591...      0
# 42  \humanovehiculo\humano_vehiculo_PNC_2014_ISAAC...      1
# 43  \vacia\NOANIMAL_ZOO_5_6_7_9\50_20210417 (25294...      0
# 44  \ave\ave_ave_WellingtonCameraTraps_SS\05081613...      1
# 45    \cervidae\Ciervo_PNC_2012_JC\a14725IM000641.JPG      1
# 46  \vaca\cow_CaltechCameraTrap\585c030e-23d2-11e8...      1
# 47  \cervidae\CERVIDREDORFALLOWDEER_ZOO_1_4\17_202...      1
# 48                        \ave\Chicken_ena24\6426.jpg      1
# 49  \vacia\NOANIMAL_ZOO_5_6_7_9\24_20210615 (7263)...      0
# 50  \ave\OTHERSPECIES_ZOO_5_6_7_9\38_20210618 (169...      1
# 51  \vacia\empty_IslandConservationCameraTraps\dom...      0
# 52  \garduna\garduna_vacías_humanos_PNC_2012_ME\a4...      1
# 53  \jabali\WILDBOAR_ZOO_5_6_7_9\20_20210219 (2902...      1
# 54  \vacia\empty_SnapshotMountainZebra\MTZ_S1_D06_...      0
# 55  \ave\bird_CaltechCameraTrap\58ce4024-23d2-11e8...      1
# 56    \vacia\vacias_PNC_2014_ISAAC\c11233IMAG0016.JPG      0
# 57  \cervidae\CERVIDREDORFALLOWDEER_ZOO_5_6_7_9\35...      1
# 58  \lince\linces_fecha_Linces2_Leo_JC\3_Lince_fle...      1
# 59  \cervidae\ciervo_PNM_2013-O_ISAAC\f11190IM0001...      1

# %%
import os
import shutil

RUTA_ORIGEN = os.path.abspath("./dataset/emptyNonEmptyDataset")
RUTA_DESTINO = os.path.abspath("./dataset/emptyNonEmptyDatasetCROP")

for index, row in dataset.iterrows():
    # Get the relative file path
    relative_path = row['file_name'].replace('\\', '/')
    
    source_path = RUTA_ORIGEN + relative_path
    destination_path = RUTA_DESTINO + relative_path

    os.makedirs(os.path.dirname(destination_path), exist_ok=True)
    
    shutil.copyfile(source_path, destination_path)
