# %% [markdown]
# # DEFINICIÓN DE PARÁMETROS

# %%
#######################################################################################################################

# Ruta hacia los CSV del dataset
train_file_relative = './data/700Train.csv'
validation_file_relative = './data/700Validation.csv'
test_file_relative = './data/700Test.csv'

# Ruta al directorio de imágenes con máscara aplicada
masked_dir_relative = '../local/output_masked'
edited_dir_relative = '../local/output_edited'

model_dir_relative = "./models"

# Ruta relativa hacia la librería ai4eutils
ai4eutils_relative = "./repos/ai4eutils"

# Ruta relativa hacia la librería CameraTraps
CameraTraps_relative = "./repos/CameraTraps"

#######################################################################################################################

# %% [markdown]
# # DEFINICIÓN PARÁMETROS CNN

# %%
#######################################################################################################################

EPOCHS = 50
LEARNING_RATE = 1e-4
BATCH_SIZE = 16

IMG_HEIGHT = IMG_WIDTH = 448

#######################################################################################################################

# %%
import os
import platform

import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt
from tensorflow import keras

from modules.dataset_utils import DatasetUtils

home = os.path.expanduser("~")

ai4utils = os.path.abspath(ai4eutils_relative)
CameraTraps = os.path.abspath(CameraTraps_relative)
train_file = os.path.abspath(train_file_relative)
validation_file = os.path.abspath(validation_file_relative)
test_file = os.path.abspath(test_file_relative)
masked_dir = os.path.abspath(masked_dir_relative)
edited_dir = os.path.abspath(edited_dir_relative)
model_dir = os.path.abspath(model_dir_relative)

try:
    os.environ['PYTHONPATH']
except KeyError:
    os.environ['PYTHONPATH'] = ""
if platform.system() == 'Windows':
    os.environ['PYTHONPATH'] += (";" + ai4utils)
    os.environ['PYTHONPATH'] += (";" + CameraTraps)
else:
    os.environ['PYTHONPATH'] += (":" + ai4utils)
    os.environ['PYTHONPATH'] += (":" + CameraTraps)

print('==============================================================================================================')
print('PYTHONPATH: ' + os.environ['PYTHONPATH'])
print('')
print('ai4eutils PATH: ' + '\t\t' + ai4utils)
print('CameraTraps PATH: ' + '\t\t' + CameraTraps)
print('Train CSV PATH: ' + '\t\t' + train_file)
print('Validation CSV PATH: ' + '\t' + validation_file)
print('Test CSV PATH: ' + '\t\t\t' + test_file)
print('masked PATH: ' + '\t\t\t' + masked_dir)
print('edited PATH: ' + '\t\t\t' + edited_dir)
print('models PATH: ' + '\t\t\t' + model_dir)
print('==============================================================================================================')
# Out:
# =======================================================================================================================================
# TensorFlow version: 2.10.0
# Is GPU available? tf.test.is_gpu_available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# =======================================================================================================================================
#
# ==============================================================================================================
# PYTHONPATH: /Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo:/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/ai4eutils:/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/CameraTraps
#
# ai4eutils PATH: 		/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/ai4eutils
# CameraTraps PATH: 		/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/CameraTraps
# Train CSV PATH: 		/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/data/700Train.csv
# Validation CSV PATH: 	/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/data/700Validation.csv
# Test CSV PATH: 			/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/data/700Test.csv
# masked PATH: 			/Users/carlos/WORKSPACE/local/output_masked
# edited PATH: 			/Users/carlos/WORKSPACE/local/output_edited
# models PATH: 			/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/models
# ==============================================================================================================

# %% [markdown]
# # Generate Datasets

# %%
custom = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1. / 255,
    horizontal_flip=True,
)

general = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1. / 255)

file_names, labels = DatasetUtils.load_dataset(train_file, edited_dir)
d = {'file_names': file_names, 'labels': labels}
train_df = pd.DataFrame(data=d, dtype=str)
train_dataset = custom.flow_from_dataframe(
    dataframe=train_df,
    directory=None,
    x_col="file_names",
    y_col="labels",
    class_mode='binary',
    shuffle=True,
    batch_size=BATCH_SIZE,
    target_size=(IMG_HEIGHT, IMG_WIDTH)
)

file_names, labels = DatasetUtils.load_dataset(validation_file, edited_dir)
d = {'file_names': file_names, 'labels': labels}
validation_df = pd.DataFrame(data=d, dtype=str)
validation_dataset = general.flow_from_dataframe(
    dataframe=validation_df,
    x_col="file_names",
    y_col="labels",
    class_mode='binary',
    shuffle=True,
    batch_size=BATCH_SIZE,
    target_size=(IMG_HEIGHT, IMG_WIDTH)
)

file_names, labels = DatasetUtils.load_dataset(test_file, edited_dir)
d = {'file_names': file_names, 'labels': labels}
test_df = pd.DataFrame(data=d, dtype=str)
test_dataset = general.flow_from_dataframe(
    dataframe=test_df,
    x_col="file_names",
    y_col="labels",
    class_mode='binary',
    shuffle=True,
    batch_size=BATCH_SIZE,
    target_size=(IMG_HEIGHT, IMG_WIDTH)
)
# Out:
# Found 1450 validated image filenames belonging to 2 classes.
# Found 312 validated image filenames belonging to 2 classes.
# Found 311 validated image filenames belonging to 2 classes.

# %% [markdown]
# # ResNet 34 Architecture

# %%
def identity_block(x, filter):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])
    x = tf.keras.layers.Activation('relu')(x)
    return x

def convolutional_block(x, filter):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same', strides = (2,2))(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    # Processing Residue with conv(1,1)
    x_skip = tf.keras.layers.Conv2D(filter, (1,1), strides = (2,2))(x_skip)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])
    x = tf.keras.layers.Activation('relu')(x)
    return x

def ResNet34(shape=(32, 32, 3), classes=10):
    # Step 1 (Setup Input Layer)
    x_input = tf.keras.layers.Input(shape)
    x = tf.keras.layers.ZeroPadding2D((3, 3))(x_input)
    # Step 2 (Initial Conv layer along with maxPool)
    x = tf.keras.layers.Conv2D(64, kernel_size=7, strides=2, padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')(x)
    # Define size of sub-blocks and initial filter size
    block_layers = [3, 4, 6, 3]
    filter_size = 64
    # Step 3 Add the Resnet Blocks
    for i in range(4):
        if i == 0:
            # For sub-block 1 Residual/Convolutional block not needed
            for j in range(block_layers[i]):
                x = identity_block(x, filter_size)
        else:
            # One Residual/Convolutional Block followed by Identity blocks
            # The filter size will go on increasing by a factor of 2
            filter_size = filter_size * 2
            x = convolutional_block(x, filter_size)
            for j in range(block_layers[i] - 1):
                x = identity_block(x, filter_size)
    # Step 4 End Dense Network
    x = tf.keras.layers.AveragePooling2D((2, 2), padding='same')(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(512, activation='relu')(x)
    x = tf.keras.layers.Dense(classes, activation='softmax')(x)
    model = tf.keras.models.Model(inputs=x_input, outputs=x, name="ResNet34")
    return model


ResNet = ResNet34(shape=(IMG_HEIGHT, IMG_WIDTH, 3), classes=1)

ResNet.summary()

ResNet.compile(
    optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=[keras.losses.BinaryCrossentropy()],
    metrics=['accuracy'])
# Out:
# Metal device set to: Apple M1
# 2022-10-18 17:23:23.905287: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-10-18 17:23:23.905422: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "ResNet34"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 448, 448, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 454, 454, 3)  0          ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 227, 227, 64  9472        ['zero_padding2d[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 227, 227, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 227, 227, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 114, 114, 64  0           ['activation[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 114, 114, 64  36928       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 114, 114, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 114, 114, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 114, 114, 64  36928       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 114, 114, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  add (Add)                      (None, 114, 114, 64  0           ['batch_normalization_2[0][0]',
#                                 )                                 'max_pooling2d[0][0]']
#
#  activation_2 (Activation)      (None, 114, 114, 64  0           ['add[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 114, 114, 64  36928       ['activation_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 114, 114, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 114, 114, 64  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 114, 114, 64  36928       ['activation_3[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 114, 114, 64  256        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  add_1 (Add)                    (None, 114, 114, 64  0           ['batch_normalization_4[0][0]',
#                                 )                                 'activation_2[0][0]']
#
#  activation_4 (Activation)      (None, 114, 114, 64  0           ['add_1[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 114, 114, 64  36928       ['activation_4[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 114, 114, 64  256        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  activation_5 (Activation)      (None, 114, 114, 64  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 114, 114, 64  36928       ['activation_5[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 114, 114, 64  256        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  add_2 (Add)                    (None, 114, 114, 64  0           ['batch_normalization_6[0][0]',
#                                 )                                 'activation_4[0][0]']
#
#  activation_6 (Activation)      (None, 114, 114, 64  0           ['add_2[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 57, 57, 128)  73856       ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 57, 57, 128)  512        ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 57, 57, 128)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 57, 57, 128)  147584      ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 57, 57, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  conv2d_9 (Conv2D)              (None, 57, 57, 128)  8320        ['activation_6[0][0]']
#
#  add_3 (Add)                    (None, 57, 57, 128)  0           ['batch_normalization_8[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  activation_8 (Activation)      (None, 57, 57, 128)  0           ['add_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 57, 57, 128)  147584      ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 57, 57, 128)  512        ['conv2d_10[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 57, 57, 128)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 57, 57, 128)  147584      ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 57, 57, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 57, 57, 128)  0           ['batch_normalization_10[0][0]',
#                                                                   'activation_8[0][0]']
#
#  activation_10 (Activation)     (None, 57, 57, 128)  0           ['add_4[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 57, 57, 128)  147584      ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 57, 57, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 57, 57, 128)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 57, 57, 128)  147584      ['activation_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 57, 57, 128)  512        ['conv2d_13[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 57, 57, 128)  0           ['batch_normalization_12[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_12 (Activation)     (None, 57, 57, 128)  0           ['add_5[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 57, 57, 128)  147584      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 57, 57, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 57, 57, 128)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 57, 57, 128)  147584      ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 57, 57, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 57, 57, 128)  0           ['batch_normalization_14[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_14 (Activation)     (None, 57, 57, 128)  0           ['add_6[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 29, 29, 256)  295168      ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 29, 29, 256)  1024       ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 29, 29, 256)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 29, 29, 256)  590080      ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 29, 29, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  conv2d_18 (Conv2D)             (None, 29, 29, 256)  33024       ['activation_14[0][0]']
#
#  add_7 (Add)                    (None, 29, 29, 256)  0           ['batch_normalization_16[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  activation_16 (Activation)     (None, 29, 29, 256)  0           ['add_7[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 29, 29, 256)  590080      ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 29, 29, 256)  1024       ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 29, 29, 256)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 29, 29, 256)  590080      ['activation_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 29, 29, 256)  1024       ['conv2d_20[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 29, 29, 256)  0           ['batch_normalization_18[0][0]',
#                                                                   'activation_16[0][0]']
#
#  activation_18 (Activation)     (None, 29, 29, 256)  0           ['add_8[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 29, 29, 256)  590080      ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 29, 29, 256)  1024       ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 29, 29, 256)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 29, 29, 256)  590080      ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 29, 29, 256)  1024       ['conv2d_22[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 29, 29, 256)  0           ['batch_normalization_20[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_20 (Activation)     (None, 29, 29, 256)  0           ['add_9[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 29, 29, 256)  590080      ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 29, 29, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 29, 29, 256)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 29, 29, 256)  590080      ['activation_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 29, 29, 256)  1024       ['conv2d_24[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 29, 29, 256)  0           ['batch_normalization_22[0][0]',
#                                                                   'activation_20[0][0]']
#
#  activation_22 (Activation)     (None, 29, 29, 256)  0           ['add_10[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 29, 29, 256)  590080      ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 29, 29, 256)  1024       ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 29, 29, 256)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 29, 29, 256)  590080      ['activation_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 29, 29, 256)  1024       ['conv2d_26[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 29, 29, 256)  0           ['batch_normalization_24[0][0]',
#                                                                   'activation_22[0][0]']
#
#  activation_24 (Activation)     (None, 29, 29, 256)  0           ['add_11[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 29, 29, 256)  590080      ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 29, 29, 256)  1024       ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 29, 29, 256)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 29, 29, 256)  590080      ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 29, 29, 256)  1024       ['conv2d_28[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 29, 29, 256)  0           ['batch_normalization_26[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_26 (Activation)     (None, 29, 29, 256)  0           ['add_12[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 15, 15, 512)  1180160     ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 15, 15, 512)  2048       ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 15, 15, 512)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 15, 15, 512)  2359808     ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 15, 15, 512)  2048       ['conv2d_30[0][0]']
#  ormalization)
#
#  conv2d_31 (Conv2D)             (None, 15, 15, 512)  131584      ['activation_26[0][0]']
#
#  add_13 (Add)                   (None, 15, 15, 512)  0           ['batch_normalization_28[0][0]',
#                                                                   'conv2d_31[0][0]']
#
#  activation_28 (Activation)     (None, 15, 15, 512)  0           ['add_13[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 15, 15, 512)  2359808     ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 15, 15, 512)  2048       ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 15, 15, 512)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 15, 15, 512)  2359808     ['activation_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 15, 15, 512)  2048       ['conv2d_33[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 15, 15, 512)  0           ['batch_normalization_30[0][0]',
#                                                                   'activation_28[0][0]']
#
#  activation_30 (Activation)     (None, 15, 15, 512)  0           ['add_14[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 15, 15, 512)  2359808     ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 15, 15, 512)  2048       ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 15, 15, 512)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 15, 15, 512)  2359808     ['activation_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 15, 15, 512)  2048       ['conv2d_35[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 15, 15, 512)  0           ['batch_normalization_32[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_32 (Activation)     (None, 15, 15, 512)  0           ['add_15[0][0]']
#
#  average_pooling2d (AveragePool  (None, 8, 8, 512)   0           ['activation_32[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 32768)        0           ['average_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 512)          16777728    ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 1)            513         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 38,084,865
# Trainable params: 38,069,633
# Non-trainable params: 15,232
# __________________________________________________________________________________________________

# %%
hist = ResNet.fit(
    train_dataset,
    steps_per_epoch=train_dataset.samples // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=validation_dataset,
    validation_steps=validation_dataset.samples // BATCH_SIZE,
    verbose=1
)
results = ResNet.evaluate(
    test_dataset,
    batch_size=BATCH_SIZE,
    verbose=1
)

fig = plt.figure(figsize=(15, 12))
fig.suptitle('ResNet 34 using edited images')

ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

ax1.plot(hist.history['loss'], color='blue', label='train loss', )
ax1.plot(hist.history['val_loss'], color='green', label='validation loss')
ax1.legend(loc="upper right")
ax2.plot(hist.history['accuracy'], color='orange', label='train accuracy')
ax2.plot(hist.history['val_accuracy'], color='red', label='validation accuracy')
ax2.legend(loc="lower right")
plt.show()
# Out:
# Epoch 1/50
# 2022-10-18 17:23:24.699078: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-10-18 17:23:26.381310: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 90/90 [==============================] - ETA: 0s - loss: 0.8008 - accuracy: 0.6632
# 2022-10-18 17:25:28.750943: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 90/90 [==============================] - 131s 1s/step - loss: 0.8008 - accuracy: 0.6632 - val_loss: 1.2036 - val_accuracy: 0.6513
# Epoch 2/50
# 90/90 [==============================] - 129s 1s/step - loss: 0.3858 - accuracy: 0.6625 - val_loss: 0.8945 - val_accuracy: 0.6579
# Epoch 3/50
# 90/90 [==============================] - 129s 1s/step - loss: 0.3360 - accuracy: 0.6632 - val_loss: 0.6247 - val_accuracy: 0.6513
# Epoch 4/50
# 90/90 [==============================] - 130s 1s/step - loss: 0.3553 - accuracy: 0.6632 - val_loss: 0.6981 - val_accuracy: 0.6645
# Epoch 5/50
# 90/90 [==============================] - 129s 1s/step - loss: 0