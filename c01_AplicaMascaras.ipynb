# %%
import os
import platform

#######################################################################################################################
# PARÁMETROS DEFINIDOS EN FUNCIÓN DEL USUARIO
#######################################################################################################################

# Ruta relativa hacia la librería ai4eutils
ai4eutils_relative = "./repos/ai4eutils"

# Ruta relativa hacia la librería CameraTraps
CameraTraps_relative = "./repos/CameraTraps"

# Ruta relativa hacia carpeta de JSON de donde se obtendrán los datos de entrada
output_json_path_relative = '../local/output_json'

# Ruta relativa hacia la carpeta destino de los ficheros JSON:
output_mask_path_relative = '../local/output_mask'

# Ruta relativa hacia la carpeta destino de los ficheros JSON:
output_masked_path_relative = '../local/output_masked'

# Poner a True si al final de la ejecución se desea mostrar las fotos en este notebook
VISUALIZAR_RESULTADOS = False

#######################################################################################################################
#######################################################################################################################

home = os.path.expanduser("~")

ai4utils = os.path.abspath(ai4eutils_relative)
CameraTraps = os.path.abspath(CameraTraps_relative)
output_json = os.path.abspath(output_json_path_relative)
output_mask = os.path.abspath(output_mask_path_relative)
output_masked = os.path.abspath(output_masked_path_relative)

try:
    os.environ['PYTHONPATH']
except KeyError:
    os.environ['PYTHONPATH'] = ""
if platform.system() == 'Windows':
    os.environ['PYTHONPATH'] += (";" + ai4utils)
    os.environ['PYTHONPATH'] += (";" + CameraTraps)
else:
    os.environ['PYTHONPATH'] += (":" + ai4utils)
    os.environ['PYTHONPATH'] += (":" + CameraTraps)

print(
    '==================================================================================================================================')
print('PYTHONPATH: ' + os.environ['PYTHONPATH'])
print('')
print('ai4eutils PATH: ' + '\t' + '\t' + ai4utils)
print('CameraTraps PATH: ' + '\t' + '\t' + CameraTraps)
print('output_json PATH: ' + '\t' + '\t' + output_json)
print('output_mask PATH: ' + '\t' + '\t' + output_mask)
print('output_masked PATH: ' + '\t' + output_masked)
print(
    '==================================================================================================================================')
# Out:
# ==================================================================================================================================
# PYTHONPATH: /Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo:/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/ai4eutils:/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/CameraTraps
#
# ai4eutils PATH: 		/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/ai4eutils
# CameraTraps PATH: 		/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/CameraTraps
# output_json PATH: 		/Users/carlos/WORKSPACE/local/output_json
# output_mask PATH: 		/Users/carlos/WORKSPACE/local/output_mask
# output_masked PATH: 	/Users/carlos/WORKSPACE/local/output_masked
# ==================================================================================================================================

# %%
# !python ./modules/aplica_mascaras.py --json_dir "$output_json" --output_mask "$output_mask" --output_masked "$output_masked"
# Out:
# ==========================================================================================
# Aplicando máscaras en 2064 imágenes...
#
#   0%|                                                  | 0/2064 [00:00<?, ?it/s]
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/vacias_PNM_2012_ME/d14980FILE0014.JPG en 0.02 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/cervidae/CERVIDREDORFALLOWDEER_ZOO_5_6_7_9/8_20210219 (111) (2021_04_15 06_16_22 UTC).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/jabali/WILDBOAR_ZOO_1_4/9_20201118 (739).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/caballo/HORSE_ZOO_1_4/28_20201117 (610).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/Nothing_mammalWeb/15759.jpg en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/zorro/Zorro_PNC_2014_JC/c16987IM000268.JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vaca/cow_CaltechCameraTrap/586adf62-23d2-11e8-a6a3-ec086b02610b.jpg en 0.01 seconds.
#   0%|▏                                         | 7/2064 [00:00<00:32, 63.86it/s]
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/cervidae/CERVIDREDORFALLOWDEER_ZOO_1_4/21_20201025 (1775).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/cervidae/ciervo_vacías_humanos_PNC_2012_ME/a6648IM000025.JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/lince/linces_fecha_Linces2_Leo_JC/2_Lince_flecha_Linces2_Leo_JC/Lince69 (15).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/NOANIMAL_ZOO_5_6_7_9/11_20210418 (3490).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/empty_SnapshotMountainZebra/MTZ_S1_G04_R3_IMAG1226.JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vaca/COW_ZOO_5_6_7_9/9_20210615 (179).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/NOANIMAL_ZOO_1_4/6_20201812 (12518).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/cervidae/deer_CaltechCameraTrap/59ec55a6-23d2-11e8-a6a3-ec086b02610b.jpg en 0.01 seconds.
#   1%|▎                                        | 15/2064 [00:00<00:28, 71.96it/s]
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/empty_IslandConservationCameraTraps/dominicanrepublic_cam0425abril2015_20130815_053815_sunp2670.jpg en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/NOANIMAL_ZOO_1_4/26_20201020 (15582).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/humanovehiculo/humanovehiculo_Caltech/598622d2-23d2-11e8-a6a3-ec086b02610b.jpg en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/zorro/Zorro
jpg en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/Nothing_mammalWeb/45980.jpg en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/gato_domestico/gato_WellingtonCameraTraps_SS/16101510520601940151.JPG en 0.01 seconds.
#  98%|██████████████████████████████████████▏| 2024/2064 [00:26<00:00, 80.46it/s]
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/mapache/raccoon_CaltechCameraTrap_ME/59f9470a-23d2-11e8-a6a3-ec086b02610b.jpg en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/NOANIMAL_ZOO_5_6_7_9/8_20210219 (608) (2021_04_15 06_16_22 UTC).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/jabali/WILDBOAR_ZOO_1_4/4_20210117 (3025).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/cervidae/ciervo_PNM_2012_ISAAC/d16007FILE0011.JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/micromamiferos/rat_IslandConservationCameraTraps/micronesia_cam09_cam09june2019_20190614170149_rcnx0004.jpg en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/meloncillo/Meloncillo_PEPE_IREC_JC/IMAG0787.JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/vacia_javi_2_JC/27_20201023 (3419).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/empty_caltechCameraTraps/59929344-23d2-11e8-a6a3-ec086b02610b.jpg en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/jabali/WILDBOAR_ZOO_5_6_7_9/20_20210219 (990) (2021_04_15 06_16_22 UTC).JPG en 0.01 seconds.
#  98%|██████████████████████████████████████▍| 2033/2064 [00:26<00:00, 81.53it/s]
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/NOANIMAL_ZOO_5_6_7_9/25_20210417 (20460).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/tejon/Tejon_PEPE_IREC_JC/PICT0119.JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vaca/Vaca4_diego_1_rev_donana/15_20201024 (7519).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/leporido/rabbit_IslandConservationCameraTraps/chile_frances022013_04052013131102.jpg en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/empty_IslandConservationCameraTraps/dominicanrepublic_cam1826julio2015_20150628_125014_img_0696.jpg en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/jabali/WILDBOAR_ZOO_1_4/7_20201118 (305).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/NOANIMAL_ZOO_1_4/7_20210115 (1096).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/empty_caltechCameraTraps/59d753b9-23d2-11e8-a6a3-ec086b02610b.jpg en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vaca/COW_ZOO_5_6_7_9/21_20210418 (1817).JPG en 0.01 seconds.
#  99%|██████████████████████████████████████▌| 2042/2064 [00:26<00:00, 81.68it/s]
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/ave/ave_Soraya_Padilla_Alumno_1_TH/STC_0223_frame040.jpg en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/gato_domestico/cat_IslandConservationCameraTraps/dominicanrepublic_cam1126junio2015_20150613_001939_img_0013.jpg en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/cervidae/ciervo_PNC_2014_ISAAC/c12561IMAG0342.JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/tejon/Tejon_Leo_Otra_fauna_PASADA_POR_LA_RED_JC/Otrafauna (1860).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/cervidae/ciervo_Javi_3_JC/7_20201025 (322).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/NOANIMAL_ZOO_5_6_7_9/24_20210418 (7624).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/empty_caltechCameraTraps/5962917e-23d2-11e8-a6a3-ec086b02610b.jpg en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/jabali/WILDBOAR_ZOO_1_4/29_20201023 (549).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/jabali/WILDBOAR_ZOO_1_4/18_20210115 (3962).JPG en 0.01 seconds.
#  99%|██████████████████████████████████████▊| 2051/2064 [00:26<00:00, 81.97it/s]
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/vacia_alumno_AM_2/30_20201021 (1233).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/cervidae/deer_CaltechCameraTrap/5971f917-23d2-11e8-a6a3-ec086b02610b.jpg en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/cervidae/cervidae_alumno_2_TH/34_20201024 (4041).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/cervidae/Ciervo_PNC_2012_JC/a14283IM000206.JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vaca/COW_ZOO_5_6_7_9/46_20210618 (908).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/zorro/zorro_PNC_2014_manuel/c27470IM000099.JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/vacia_alumno_1_TH/Nada (46)_frame110.jpg en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/empty_caltechCameraTraps/59e43ff0-23d2-11e8-a6a3-ec086b02610b.jpg en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/NOANIMAL_ZOO_1_4/6_20201812 (13281).JPG en 0.01 seconds.
# 100%|██████████████████████████████████████▉| 2060/2064 [00:27<00:00, 82.11it/s]
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/vacia_alumno_2_2_TH_JC/27_20201023 (7900).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/jabali/WILDBOAR_ZOO_5_6_7_9/1_20210219 (352) (2021_04_15 06_16_22 UTC).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/caballo/caballos_simone/4_20201220 (7543).JPG en 0.01 seconds.
#
#
# Aplicada máscara en imagen /Users/carlos/WORKSPACE/DATASETs/emptyNonEmptyDataset/vacia/empty_caltechCameraTraps/5992934b-23d2-11e8-a6a3-ec086b02610b.jpg en 0.01 seconds.
# 100%|███████████████████████████████████████| 2064/2064 [00:27<00:00, 76.26it/s]
#
# ==========================================================================================
# De media, por cada imagen:
# Ha tomado 0.01 seconds en aplicar la máscara, con desviación de 0 seconds
# ==========================================================================================
#
# Resultados guardados en: /Users/carlos/WORKSPACE/local/output_masked
#
# ==========================================================================================

# %%
if VISUALIZAR_RESULTADOS:
    import os
    import glob
    from PIL import Image
    from tqdm import tqdm

    image_extensions = ['.png']


    def is_image_file(s):
        ext = os.path.splitext(s)[1]
        return ext.lower() in image_extensions


    def find_image_files(strings):
        return [s for s in strings if is_image_file(s)]


    def find_images(dir_name):
        strings = glob.glob(os.path.join(dir_name, '*.*'))
        image_strings = find_image_files(strings)
        return image_strings


    image_file_names = find_images(output_masked)

    for image_file in tqdm(image_file_names):
        print(image_file)
        im = Image.open(image_file)
        display(im)
        print('')
