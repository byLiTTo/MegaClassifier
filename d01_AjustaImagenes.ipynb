# %%
import os
import platform

#######################################################################################################################
# PARÁMETROS DEFINIDOS EN FUNCIÓN DEL USUARIO
#######################################################################################################################

# Ruta relativa hacia la librería ai4eutils
ai4eutils_relative = "./repos/ai4eutils"

# Ruta relativa hacia la librería CameraTraps
CameraTraps_relative = "./repos/CameraTraps"

# Ruta relativa hacia carpeta de JSON de donde se obtendrán los datos de entrada
output_json_path_relative = '../local/output_json'

# Ruta relativa hacia carpeta donde se encuentran las imágenes con máscara aplicada
output_masked_path_relative = '../local/output_masked'

# Ruta relativa hacia la carpeta destino output_edited, se guardarán las imágenes ajustadas
output_edited_path_relative = '../local/output_edited'

# Poner a True si al final de la ejecución se desea mostrar las fotos en este notebook
VISUALIZAR_RESULTADOS = False

#######################################################################################################################
#######################################################################################################################

home = os.path.expanduser("~")

ai4utils = os.path.abspath(ai4eutils_relative)
CameraTraps = os.path.abspath(CameraTraps_relative)
output_json = os.path.abspath(output_json_path_relative)
output_masked = os.path.abspath(output_masked_path_relative)
output_edited = os.path.abspath(output_edited_path_relative)

try:
    os.environ['PYTHONPATH']
except KeyError:
    os.environ['PYTHONPATH'] = ""
if platform.system() == 'Windows':
    os.environ['PYTHONPATH'] += (";" + ai4utils)
    os.environ['PYTHONPATH'] += (";" + CameraTraps)
else:
    os.environ['PYTHONPATH'] += (":" + ai4utils)
    os.environ['PYTHONPATH'] += (":" + CameraTraps)

print(
    '==================================================================================================================================')
print('PYTHONPATH: ' + os.environ['PYTHONPATH'])
print('')
print('ai4eutils PATH: ' + '\t' + '\t' + ai4utils)
print('CameraTraps PATH: ' + '\t' + '\t' + CameraTraps)
print('output_json PATH: ' + '\t' + '\t' + output_json)
print('output_masked PATH: ' + '\t' + output_masked)
print('output_edited PATH: ' + '\t' + output_edited)
print(
    '==================================================================================================================================')
# Out:
# ==================================================================================================================================
# PYTHONPATH: /Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo:/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/ai4eutils:/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/CameraTraps
#
# ai4eutils PATH: 		/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/ai4eutils
# CameraTraps PATH: 		/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/CameraTraps
# output_json PATH: 		/Users/carlos/WORKSPACE/local/output_json
# output_masked PATH: 	/Users/carlos/WORKSPACE/local/output_masked
# output_edited PATH: 	/Users/carlos/WORKSPACE/local/output_edited
# ==================================================================================================================================

# %%
# !python ./modules/prepara_imagenes.py --json_dir "$output_json" --output_masked "$output_masked" --output_edited "$output_edited"
# Out:
# ==========================================================================================
# Ajustando 2064 imágenes...
#
#   0%|                                                  | 0/2064 [00:00<?, ?it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/d14980file0014.png en 0 seconds.
#
# ./modules/prepara_imagenes.py:107: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   im = im.resize(new_size, Image.ANTIALIAS)
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/8_20210219 (111) (2021_04_15 06_16_22 utc).png en 0.12 seconds.
#   0%|                                          | 2/2064 [00:00<03:54,  8.77it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/9_20201118 (739).png en 0.01 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/28_20201117 (610).png en 0.06 seconds.
#   0%|                                          | 4/2064 [00:00<02:52, 11.94it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/15759.png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/c16987im000268.png en 0.06 seconds.
#   0%|                                          | 6/2064 [00:00<02:35, 13.19it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/586adf62-23d2-11e8-a6a3-ec086b02610b.png en 0.09 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/21_20201025 (1775).png en 0.05 seconds.
#   0%|▏                                         | 8/2064 [00:00<03:06, 11.03it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/
/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/f15538imag0311.png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/neovis 2_frame140.png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/2_20201117 (5162).png en 0.15 seconds.
#   9%|███▊                                    | 196/2064 [00:14<02:50, 10.96it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/6355imag0010.png en 0.09 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/orycun (23)_frame120.png en 0 seconds.
#  10%|███▊                                    | 198/2064 [00:14<02:39, 11.67it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/c15207im000002.png en 0.05 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/25_20210417 (12515).png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/d16366im000042.png en 0.06 seconds.
#  10%|███▉                                    | 201/2064 [00:14<02:24, 12.93it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/11_20210418 (2885).png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/6_20201812 (8753).png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/14091511222602359703.png en 0.02 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/b14186im000437.png en 0.06 seconds.
#  10%|███▉                                    | 205/2064 [00:14<01:54, 16.27it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/15_20210117 (938).png en 0.02 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/mtz_s1_d05_r1_imag0469.png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/imag0029_frame260.png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/13_20210218 (1384) (2021_04_15 06_16_22 utc).png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/d11158im000555.png en 0.02 seconds.
#  10%|████                                    | 210/2064 [00:14<01:25, 21.75it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/31_20201117 (187).png en 0.05 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/21_20210418 (2055).png en 0.05 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/dominicanrepublic_cam10717mayo2017_20170310_053726_img_0005.png en 0 seconds.
#  10%|████▏                                   | 213/2064 [00:14<01:34, 19.50it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/e2611im000483.png en 0.11 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/37_20201024 (501).png en 0.01 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/11_20210114 (173).png en 0 seconds.
#  10%|████▏                                   | 216/2064 [00:15<01:42, 17.98it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/17_20210418 (232).png en 0.09 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/0008305.png en 0.03 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/5892b44a-23d2-11e8-a6a3-ec086b02610b.png en 0.01 seconds.
#  11%|████▏                                   | 219/2064 [00:15<01:46, 17.29it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/5a116b82-23d2-11e8-a6a3-ec086b02610b.png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/37_20210115 (542).png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/a30060im000231.png en 0.07 seconds.
#  11%|████▎                                   | 222/2064 [00:15<01:40, 18.27it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/59531ca7-23d2-11e8-a6a3-ec086b02610b.png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/59260e79-23d2-11e8-a6a3-ec086b02610b.png en 0.23 seconds.
#  11%|████▎                                   | 224/2064 [00:15<02:33, 11.95it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/21_20201025 (1732).png en 0.05 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/4_20210117 (2562).png en 0.12 seconds.
#  11%|████▍                                   | 226/2064 [00:16<02:50, 10.80it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/34_20201024 (4426).png en 0.06 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/5983088d-23d2-11e8-a6a3-ec086b02610b.png en 0 seconds.
#  11%|████▍                                   | 228/2064 [00:16<02:31, 12.14it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/e1395imag0092.png en 0.01 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/e4923im000043.png en 0.24 seconds.
#  11%|████▍                                   | 230/2064 [00:16<03:20,  9.14it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/dominicanrepublic_cam1826julio2015_20150716_105304_img_2509.png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/micronesia_cam16april2019_20190413_090500_rcnx0322.png en 0.03 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/37_20210220 (693) (2021_04_15 06_16_22 utc).png en 0.01 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/597389d2-23d2-11e8-a6a3-ec086b02610b.png en 0.12 seconds.
#  11%|████▌                                   | 234/2064 [00:16<02:51, 10.69it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/18_20201024 (160).png en 0.01 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/cdb_s1_c07_r1_imag2272.png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/mtz_s1_d07_r1_imag2446.png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/8621imag0160.png en 0.05 seconds.
#  12%|████▌                                   | 238/2064 [00:16<02:06, 14.41it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/imag1458_(2).png en 0.01 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/7435im000010.png en 0.04 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/chile_frances022013_1405201383400.png en 0.01 seconds.
#  12%|████▋                                   | 241/2064 [00:17<01:48, 16.80it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/a49254im000752.png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/35_20210218 (1528) (2021_04_15 06_16_22 utc).png en 0.04 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/mtz_s1_g04_r3_imag3902.png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/eno_s1_d06_r1_imag3680.png en 0.16 seconds.
#  12%|████▋                                   | 245/2064 [00:17<02:01, 14.99it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/2_20210319 (1255).png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/mtz_s1_e06_r3_imag1221.png en 0.03 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/lince134 (109).png en 0.01 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/220916145238016b8834.png en 0.01 seconds.
#  12%|████▊                                   | 249/2064 [00:17<01:37, 18.69it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/eno_s1_d06_r1_imag0556.png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/34567.png en 0.03 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/21_20210418 (1437).png en 0.18 seconds.
#  12%|████▉                                   | 252/2064 [00:17<02:05, 14.44it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/a15713imag0102.png en 0.01 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/24_20210418 (5149).png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/c3839imag0178.png en 0.01 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/34_20201024 (7001).png en 0.05 seconds.
#  12%|████▉                                   | 256/2064 [00:17<01:44, 17.35it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/f13286imag0317.png en 0.02 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/28_20
png en 0.01 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/a18534im000128.png en 0.05 seconds.
#  65%|█████████████████████████▎             | 1338/2064 [01:25<00:42, 16.89it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/34_20210115 (6978).png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/37_20201215 (2631).png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/15_20210219 (4317) (2021_04_15 06_16_22 utc).png en 0.01 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/f21265im000763.png en 0.04 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/a34989imag0105.png en 0 seconds.
#  65%|█████████████████████████▍             | 1343/2064 [01:25<00:32, 22.06it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/5a163ed3-23d2-11e8-a6a3-ec086b02610b.png en 0.03 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/15_20201117 (978).png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/15_20210219 (8413) (2021_04_15 06_16_22 utc).png en 0.15 seconds.
#  65%|█████████████████████████▍             | 1346/2064 [01:25<00:42, 16.89it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/38_20210219 (1412) (2021_04_15 06_16_22 utc).png en 0.01 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/c12278imag0030.png en 0.14 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/89412.png en 0 seconds.
#  65%|█████████████████████████▍             | 1349/2064 [01:26<00:45, 15.62it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/49_20210418 (17312).png en 0 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/34_20201024 (2384).png en 0.01 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/15_20210117 (2940).png en 0.03 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/24_20201019 (8703).png en 0.07 seconds.
#  66%|█████████████████████████▌             | 1353/2064 [01:26<00:43, 16.50it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/21_20200113 (506) (2021_04_15 06_16_22 utc).png en 0.15 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/50_20210408 (11977).png en 0 seconds.
#  66%|█████████████████████████▌             | 1355/2064 [01:26<00:49, 14.25it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/c22702im000098.png en 0.18 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/micronesia_cam09_cam09june2019_20190622171303_rcnx0681.png en 0.07 seconds.
#  66%|█████████████████████████▋             | 1357/2064 [01:26<01:07, 10.40it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/090116124128049c1023.png en 0.04 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/59216583-23d2-11e8-a6a3-ec086b02610b.png en 0.01 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/b12158imag0613.png en 0.08 seconds.
#  66%|█████████████████████████▋             | 1360/2064 [01:27<00:58, 11.96it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/21_20201025 (4027).png en 0.08 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/19_20210219 (1219) (2021_04_15 06_16_22 utc).png en 0.01 seconds.
#  66%|█████████████████████████▋             | 1362/2064 [01:27<00:56, 12.33it/s]
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/10_20210417 (1083).png en 0.01 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/a43103imag0017.png en 0.03 seconds.
#
#
# Ajustada imagen /Users/carlos/WORKSPACE/local/output_masked/a2904im000002.png en 0.16 seconds.
# ^C
#  66%|█████████████████████████▊             | 1368/2064 [01:27<00:44, 15.59it/s]
# Traceback (most recent call last):
#   File "./modules/prepara_imagenes.py", line 270, in <module>
#     main()
#   File "./modules/prepara_imagenes.py", line 261, in main
#     run(input_file_names=input_file_names, output_masked=args.output_masked, output_edited=args.output_edited)
#   File "./modules/prepara_imagenes.py", line 150, in run
#     np_image = np.asarray(Image.open(image_path), dtype='uint8')
#   File "/Users/carlos/miniforge3/envs/TFG/lib/python3.8/site-packages/PIL/Image.py", line 687, in __array_interface__
#     new["data"] = self.tobytes()
#   File "/Users/carlos/miniforge3/envs/TFG/lib/python3.8/site-packages/PIL/Image.py", line 729, in tobytes
#     self.load()
#   File "/Users/carlos/miniforge3/envs/TFG/lib/python3.8/site-packages/PIL/ImageFile.py", line 257, in load
#     n, err_code = decoder.decode(b)
# KeyboardInterrupt

# %%
if VISUALIZAR_RESULTADOS:
    import os
    import glob
    from PIL import Image
    from tqdm import tqdm

    image_extensions = ['.png']


    def is_image_file(s):
        ext = os.path.splitext(s)[1]
        return ext.lower() in image_extensions


    def find_image_files(strings):
        return [s for s in strings if is_image_file(s)]


    def find_images(dir_name):
        strings = glob.glob(os.path.join(dir_name, '*.*'))
        image_strings = find_image_files(strings)
        return image_strings


    image_file_names = find_images(output_edited)

    for image_file in tqdm(image_file_names):
        print(image_file)
        im = Image.open(image_file)
        display(im)
        print('\n\n')
