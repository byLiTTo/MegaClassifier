# %%
import os
import platform

#######################################################################################################################
# PARÁMETROS DEFINIDOS EN FUNCIÓN DEL USUARIO
#######################################################################################################################

# Ruta relativa hacia la librería ai4eutils
ai4eutils_relative = "./repos/ai4eutils"

# Ruta relativa hacia la librería CameraTraps
CameraTraps_relative = "./repos/CameraTraps"

# Ruta relativa hacia carpeta de JSON de donde se obtendrán los datos de entrada
output_json_path_relative = '../local/output_json'

# Ruta relativa hacia carpeta donde se encuentran las imágenes con máscara aplicada
output_masked_path_relative = '../local/output_masked'

# Ruta relativa hacia la carpeta destino output_edited, se guardarán las imágenes ajustadas
output_edited_path_relative = '../local/output_edited'

# Poner a True si al final de la ejecución se desea mostrar las fotos en este notebook
VISUALIZAR_RESULTADOS = False

#######################################################################################################################
#######################################################################################################################

home = os.path.expanduser("~")

ai4utils = os.path.abspath(ai4eutils_relative)
CameraTraps = os.path.abspath(CameraTraps_relative)
output_json = os.path.abspath(output_json_path_relative)
output_masked = os.path.abspath(output_masked_path_relative)
output_edited = os.path.abspath(output_edited_path_relative)

try:
    os.environ['PYTHONPATH']
except KeyError:
    os.environ['PYTHONPATH'] = ""
if platform.system() == 'Windows':
    os.environ['PYTHONPATH'] += (";" + ai4utils)
    os.environ['PYTHONPATH'] += (";" + CameraTraps)
else:
    os.environ['PYTHONPATH'] += (":" + ai4utils)
    os.environ['PYTHONPATH'] += (":" + CameraTraps)

print(
    '==================================================================================================================================')
print('PYTHONPATH: ' + os.environ['PYTHONPATH'])
print('')
print('ai4eutils PATH: ' + '\t' + '\t' + ai4utils)
print('CameraTraps PATH: ' + '\t' + '\t' + CameraTraps)
print('output_json PATH: ' + '\t' + '\t' + output_json)
print('output_masked PATH: ' + '\t' + output_masked)
print('output_edited PATH: ' + '\t' + output_edited)
print(
    '==================================================================================================================================')
# Out:
# ==================================================================================================================================
# PYTHONPATH: /Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo:/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/ai4eutils:/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/CameraTraps
#
# ai4eutils PATH: 		/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/ai4eutils
# CameraTraps PATH: 		/Users/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/CameraTraps
# output_json PATH: 		/Users/carlos/WORKSPACE/local/output_json
# output_masked PATH: 	/Users/carlos/WORKSPACE/local/output_masked
# output_edited PATH: 	/Users/carlos/WORKSPACE/local/output_edited
# ==================================================================================================================================

# %%
# !python ./modules/prepara_imagenes.py --json_dir "$output_json" --output_masked "$output_masked" --output_edited "$output_edited"
# Out:
# ==========================================================================================
# Generando máscaras de 2064 imágenes...
#
#   0%|                                                  | 0/2064 [00:00<?, ?it/s]
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/d14980file0014.png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/8_20210219 (111) (2021_04_15 06_16_22 utc).png en 0.13 seconds.
#   0%|                                          | 2/2064 [00:00<04:01,  8.52it/s]
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/9_20201118 (739).png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/28_20201117 (610).png en 0.02 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/15759.png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/c16987im000268.png en 0.06 seconds.
#   0%|                                          | 6/2064 [00:00<02:10, 15.71it/s]
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/586adf62-23d2-11e8-a6a3-ec086b02610b.png en 0.1 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/21_20201025 (1775).png en 0.06 seconds.
#   0%|▏                                         | 8/2064 [00:00<02:52, 11.91it/s]
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/a6648im000025.png en 0.03 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/lince69 (15).png en 0.04 seconds.
#   0%|▏                                        | 10/2064 [00:00<02:40, 12.76it/s]
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/11_20210418 (3490).png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/mtz_s1_g04_r3_imag1226.png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/9_20210615 (179).png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/6_20201812 (12518).png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/
/s]
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/59f9470a-23d2-11e8-a6a3-ec086b02610b.png en 0.02 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/8_20210219 (608) (2021_04_15 06_16_22 utc).png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/4_20210117 (3025).png en 0.03 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/d16007file0011.png en 0.01 seconds.
#  98%|██████████████████████████████████████▎| 2028/2064 [02:00<00:01, 26.78it/s]
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/micronesia_cam09_cam09june2019_20190614170149_rcnx0004.png en 0.01 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/imag0787.png en 0.01 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/27_20201023 (3419).png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/59929344-23d2-11e8-a6a3-ec086b02610b.png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/20_20210219 (990) (2021_04_15 06_16_22 utc).png en 0.01 seconds.
#  98%|██████████████████████████████████████▍| 2033/2064 [02:00<00:00, 31.73it/s]
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/25_20210417 (20460).png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/pict0119.png en 0.06 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/15_20201024 (7519).png en 0.07 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/chile_frances022013_04052013131102.png en 0.01 seconds.
#  99%|██████████████████████████████████████▍| 2037/2064 [02:01<00:01, 25.55it/s]
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/dominicanrepublic_cam1826julio2015_20150628_125014_img_0696.png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/7_20201118 (305).png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/7_20210115 (1096).png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/59d753b9-23d2-11e8-a6a3-ec086b02610b.png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/21_20210418 (1817).png en 0.12 seconds.
#  99%|██████████████████████████████████████▌| 2042/2064 [02:01<00:00, 23.79it/s]
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/stc_0223_frame040.png en 0.01 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/dominicanrepublic_cam1126junio2015_20150613_001939_img_0013.png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/c12561imag0342.png en 0.06 seconds.
#  99%|██████████████████████████████████████▋| 2045/2064 [02:01<00:00, 24.18it/s]
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/otrafauna (1860).png en 0.09 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/7_20201025 (322).png en 0.02 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/24_20210418 (7624).png en 0 seconds.
#  99%|██████████████████████████████████████▋| 2048/2064 [02:01<00:00, 21.48it/s]
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/5962917e-23d2-11e8-a6a3-ec086b02610b.png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/29_20201023 (549).png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/18_20210115 (3962).png en 0.01 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/30_20201021 (1233).png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/5971f917-23d2-11e8-a6a3-ec086b02610b.png en 0.05 seconds.
#  99%|██████████████████████████████████████▊| 2053/2064 [02:01<00:00, 24.33it/s]
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/34_20201024 (4041).png en 0.05 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/a14283im000206.png en 0.06 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/46_20210618 (908).png en 0 seconds.
# 100%|██████████████████████████████████████▊| 2056/2064 [02:02<00:00, 21.57it/s]
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/c27470im000099.png en 0.09 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/nada (46)_frame110.png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/59e43ff0-23d2-11e8-a6a3-ec086b02610b.png en 0 seconds.
# 100%|██████████████████████████████████████▉| 2059/2064 [02:02<00:00, 20.10it/s]
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/6_20201812 (13281).png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/27_20201023 (7900).png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/1_20210219 (352) (2021_04_15 06_16_22 utc).png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/4_20201220 (7543).png en 0 seconds.
#
#
# Generada máscara de imagen /Users/carlos/WORKSPACE/local/output_masked/5992934b-23d2-11e8-a6a3-ec086b02610b.png en 0 seconds.
# 100%|███████████████████████████████████████| 2064/2064 [02:02<00:00, 16.88it/s]
#
# ==========================================================================================
# De media, por cada imagen:
# Ha tomado 0.03 seconds en generar la máscara, con desviación de 0.06 seconds
# ==========================================================================================
#
# Resultados guardados en: /Users/carlos/WORKSPACE/local/output_edited
#
# ==========================================================================================

# %%
if VISUALIZAR_RESULTADOS:
    import os
    import glob
    from PIL import Image
    from tqdm import tqdm

    image_extensions = ['.png']


    def is_image_file(s):
        ext = os.path.splitext(s)[1]
        return ext.lower() in image_extensions


    def find_image_files(strings):
        return [s for s in strings if is_image_file(s)]


    def find_images(dir_name):
        strings = glob.glob(os.path.join(dir_name, '*.*'))
        image_strings = find_image_files(strings)
        return image_strings


    image_file_names = find_images(output_edited)

    for image_file in tqdm(image_file_names):
        print(image_file)
        im = Image.open(image_file)
        display(im)
        print('\n\n')
