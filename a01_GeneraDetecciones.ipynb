# %%
import os
import platform
import tensorflow as tf

from datetime import datetime
now = datetime.now()

#########################################################################################################################################################
# PARAMETROS DEFINIDOS EN FUNCION DEL USUARIO
#########################################################################################################################################################

# Ruta relativa hacia la librería ai4eutils
ai4eutils_relative = "./repos/ai4eutils"

# Ruta relativa hacia la librería CameraTraps
CameraTraps_relative = "./repos/CameraTraps"

# Ruta relativa hacia carpeta de imagenes de entrada
images_dir_relative = './input'

# Ruta relativa hacia la carpeta destino de los ficheros JSON:
output_json_path_relative = ('./output_json')


# Ruta relativa al modelo
model_relative = './models/megadetector_v4_1_0.pb'

#########################################################################################################################################################
#########################################################################################################################################################

home = os.path.expanduser("~")

ai4utils = os.path.abspath(ai4eutils_relative)
CameraTraps = os.path.abspath(CameraTraps_relative)
images_dir = os.path.abspath(images_dir_relative)
output_json = os.path.abspath(output_json_path_relative)
model = os.path.abspath(model_relative)

try:
    os.environ['PYTHONPATH']
except KeyError:
    os.environ['PYTHONPATH'] = ""
if platform.system() == 'Windows':
    os.environ['PYTHONPATH'] += (";" + ai4utils)
    os.environ['PYTHONPATH'] += (";" + CameraTraps)
else:
    os.environ['PYTHONPATH'] += (":" + ai4utils)
    os.environ['PYTHONPATH'] += (":" + CameraTraps)

print('=======================================================================================================================================')
print('PYTHONPATH: ' + os.environ['PYTHONPATH'])
print('ai4eutils PATH: ' + ai4utils)
print('CameraTraps PATH: ' + CameraTraps)
print('input PATH: ' + images_dir)
print('output_json PATH: ' + output_json)
print('modelo: ' + model)
print('=======================================================================================================================================')
# Out:
# 2022-06-30 11:00:11.993501: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# =======================================================================================================================================
# PYTHONPATH: /home/carlos/.vscode/extensions/ms-toolsai.jupyter-2022.5.1001601848/pythonFiles:/home/carlos/.vscode/extensions/ms-toolsai.jupyter-2022.5.1001601848/pythonFiles/lib/python:/home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/ai4eutils:/home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/CameraTraps
# ai4eutils PATH: /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/ai4eutils
# CameraTraps PATH: /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/CameraTraps
# input PATH: /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input
# output_json PATH: /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/output_json
# modelo: /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/models/megadetector_v4_1_0.pb
# =======================================================================================================================================

# %%
# !python ./modules/genera_detecciones.py "$model" --image_dir "$images_dir" --output_dir "$output_json"
# Out:
# 2022-06-30 10:58:00.052914: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# ==========================================================================================
# TensorFlow version: 2.4.1
# 2022-06-30 10:58:00.877538: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-06-30 10:58:00.878151: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-06-30 10:58:00.906016: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 10:58:00.906277: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1050 Ti with Max-Q Design computeCapability: 6.1
# coreClock: 1.2905GHz coreCount: 6 deviceMemorySize: 3.95GiB deviceMemoryBandwidth: 104.43GiB/s
# 2022-06-30 10:58:00.906304: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-30 10:58:00.907530: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-06-30 10:58:00.907561: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-06-30 10:58:00.908692: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-06-30 10:58:00.908878: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-06-30 10:58:00.910086: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-06-30 10:58:00.910760: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-06-30 10:58:00.913361: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-06-30 10:58:00.913458: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 10:58:00.913716: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 10:58:00.913895: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# Is GPU available? tf.test.is_gpu_available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ==========================================================================================
# ==========================================================================================
# Ejecutando detector en 10 imágenes...
# ==========================================================================================
# TFDetector: Loading graph...
# TFDetector: Detection graph loaded.
# ==========================================================================================
# 2022-06-30 10:58:05.511109: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-30 10:58:05.511633: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-06-30 10:58:05.511845: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 10:58:05.512112: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1050 Ti with Max-Q Design computeCapability: 6.1
# coreClock: 1.2905GHz coreCount: 6 deviceMemorySize: 3.95GiB deviceMemoryBandwidth: 104.43GiB/s
# 2022-06-30 10:58:05.512139: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-30 10:58:05.512156: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-06-30 10:58:05.512167: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-06-30 10:58:05.512178: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-06-30 10:58:05.512189: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-06-30 10:58:05.512200: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-06-30 10:58:05.512211: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-06-30 10:58:05.512225: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-06-30 10:58:05.512279: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 10:58:05.512491: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 10:58:05.512674: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-06-30 10:58:05.512715: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-30 10:58:05.828612: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-06-30 10:58:05.828647: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-06-30 10:58:05.828655: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-06-30 10:58:05.828793: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 10:58:05.829053: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 10:58:05.829263: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 10:58:05.829451: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 3010 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1050 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 6.1)
# ==========================================================================================
# Modelo cargado en: 4.92 seconds.
# ==========================================================================================
#   0%|                                                    | 0/10 [00:00<?, ?it/s]2022-06-30 10:58:06.265684: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:196] None of the MLIR optimization passes are enabled (registered 0 passes)
# 2022-06-30 10:58:06.476790: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2199995000 Hz
# 2022-06-30 10:58:12.975893: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-06-30 10:58:13.113636: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-06-30 10:58:16.677860: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-06-30 10:58:19.280886: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.31GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/3.jpg en 15.45 seconds.
#  10%|████▍                                       | 1/10 [00:15<02:19, 15.46s/it]Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/1.jpg en 2.29 seconds.
#  20%|████████▊                                   | 2/10 [00:17<01:01,  7.72s/it]2022-06-30 10:58:26.708297: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/9.jpg en 4.66 seconds.
#  30%|█████████████▏                              | 3/10 [00:22<00:44,  6.33s/it]2022-06-30 10:58:28.549163: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-06-30 10:58:29.044216: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.07GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-06-30 10:58:30.057134: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.62GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-06-30 10:58:31.553132: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/6.jpg en 4.99 seconds.
#  40%|█████████████████▌                          | 4/10 [00:27<00:34,  5.81s/it]2022-06-30 10:58:36.230576: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/2.jpg en 4.51 seconds.
#  50%|██████████████████████                      | 5/10 [00:31<00:26,  5.34s/it]2022-06-30 10:58:39.515709: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.62GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-06-30 10:58:40.888180: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/5.jpeg en 4.78 seconds.
#  60%|██████████████████████████▍                 | 6/10 [00:36<00:20,  5.15s/it]Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/10.jpg en 4.59 seconds.
#  70%|██████████████████████████████▊             | 7/10 [00:41<00:14,  4.97s/it]Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/8.jpg en 2.25 seconds.
#  80%|███████████████████████████████████▏        | 8/10 [00:43<00:08,  4.10s/it]Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/4.jpeg en 4.78 seconds.
#  90%|███████████████████████████████████████▌    | 9/10 [00:48<00:04,  4.32s/it]Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/7.jpg en 2.41 seconds.
# 100%|███████████████████████████████████████████| 10/10 [00:50<00:00,  5.08s/it]
# ==========================================================================================
# Fichero de salida guardado en /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/output_json/7.json
# ==========================================================================================
# ==========================================================================================
# De media, por cada imagen,
# Ha tomado 0.01 seconds en cargar, con desviación de 0.01 seconds
# Ha tomado 5.07 seconds en procesar, con desviación de 3.82 seconds
# ==========================================================================================
# ==========================================================================================
