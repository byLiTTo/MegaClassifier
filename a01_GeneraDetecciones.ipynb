# %%
import os
import platform
import tensorflow as tf

from datetime import datetime
now = datetime.now()

#########################################################################################################################################################
# PARAMETROS DEFINIDOS EN FUNCION DEL USUARIO

# Ruta relativa hacia la librería ai4eutils
ai4eutils_relative = "./repos/ai4eutils"

# Ruta relativa hacia la librería CameraTraps
CameraTraps_relative = "./repos/CameraTraps"

# Ruta relativa hacia carpeta de imagenes de entrada
images_dir_relative = './input'

# Ruta relativa hacia la carpeta destino de los ficheros JSON:
output_json_path_relative = ('./output_json')


# Ruta relativa al modelo
model_relative = './models/megadetector_v4_1_0.pb'

#########################################################################################################################################################

home = os.path.expanduser("~")

ai4utils = os.path.abspath(ai4eutils_relative)
CameraTraps = os.path.abspath(CameraTraps_relative)
images_dir = os.path.abspath(images_dir_relative)
output_json = os.path.abspath(output_json_path_relative)
model = os.path.abspath(model_relative)

try:
    os.environ['PYTHONPATH']
except KeyError:
    os.environ['PYTHONPATH'] = ""
if platform.system() == 'Windows':
    os.environ['PYTHONPATH'] += (";" + ai4utils)
    os.environ['PYTHONPATH'] += (";" + CameraTraps)
else:
    os.environ['PYTHONPATH'] += (":" + ai4utils)
    os.environ['PYTHONPATH'] += (":" + CameraTraps)

print('=======================================================================================================================================')
print('PYTHONPATH: ' + os.environ['PYTHONPATH'])
print('ai4eutils PATH: ' + ai4utils)
print('CameraTraps PATH: ' + CameraTraps)
print('input PATH: ' + images_dir)
print('output_json PATH: ' + output_json)
print('modelo: ' + model)
print('=======================================================================================================================================')
# Out:
# =======================================================================================================================================
# PYTHONPATH: /home/carlos/.vscode/extensions/ms-toolsai.jupyter-2022.5.1001601848/pythonFiles:/home/carlos/.vscode/extensions/ms-toolsai.jupyter-2022.5.1001601848/pythonFiles/lib/python:/home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/ai4eutils:/home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/CameraTraps:/home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/ai4eutils:/home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/CameraTraps
# ai4eutils PATH: /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/ai4eutils
# CameraTraps PATH: /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/CameraTraps
# input PATH: /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input
# output_json PATH: /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/output_json
# modelo: /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/models/megadetector_v4_1_0.pb
# =======================================================================================================================================

# %%
# !python ./modules/genera_detecciones.py "$model" --image_dir "$images_dir" --output_dir "$output_json"
# Out:
# 2022-06-30 12:07:47.588588: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# ==========================================================================================
# TensorFlow version: 2.4.1
# 2022-06-30 12:07:48.372531: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-06-30 12:07:48.373247: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-06-30 12:07:48.401150: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 12:07:48.401364: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1050 Ti with Max-Q Design computeCapability: 6.1
# coreClock: 1.2905GHz coreCount: 6 deviceMemorySize: 3.95GiB deviceMemoryBandwidth: 104.43GiB/s
# 2022-06-30 12:07:48.401383: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-30 12:07:48.402533: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-06-30 12:07:48.402563: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-06-30 12:07:48.403631: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-06-30 12:07:48.403808: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-06-30 12:07:48.405358: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-06-30 12:07:48.406093: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-06-30 12:07:48.408758: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-06-30 12:07:48.408890: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 12:07:48.409149: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 12:07:48.409320: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# Is GPU available? tf.test.is_gpu_available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ==========================================================================================
# ==========================================================================================
# Ejecutando detector en 10 imágenes...
# ==========================================================================================
# TFDetector: Loading graph...
# TFDetector: Detection graph loaded.
# ==========================================================================================
# 2022-06-30 12:07:52.876156: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-30 12:07:52.876972: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-06-30 12:07:52.877107: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 12:07:52.877324: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1050 Ti with Max-Q Design computeCapability: 6.1
# coreClock: 1.2905GHz coreCount: 6 deviceMemorySize: 3.95GiB deviceMemoryBandwidth: 104.43GiB/s
# 2022-06-30 12:07:52.877350: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-30 12:07:52.877367: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-06-30 12:07:52.877378: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-06-30 12:07:52.877389: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-06-30 12:07:52.877400: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-06-30 12:07:52.877411: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-06-30 12:07:52.877422: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-06-30 12:07:52.877434: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-06-30 12:07:52.877479: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 12:07:52.877686: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 12:07:52.877855: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-06-30 12:07:52.877879: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-30 12:07:53.175779: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-06-30 12:07:53.175816: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-06-30 12:07:53.175823: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-06-30 12:07:53.175971: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 12:07:53.176264: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 12:07:53.176484: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 12:07:53.176732: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 3112 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1050 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 6.1)
# ==========================================================================================
# Modelo cargado en: 4.77 seconds.
# ==========================================================================================
#   0%|                                                    | 0/10 [00:00<?, ?it/s]2022-06-30 12:07:53.619233: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:196] None of the MLIR optimization passes are enabled (registered 0 passes)
# 2022-06-30 12:07:53.824728: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2199995000 Hz
# 2022-06-30 12:07:59.948728: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-06-30 12:08:00.071179: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-06-30 12:08:03.464901: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-06-30 12:08:05.988833: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.31GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/3.jpg en 14.72 seconds.
#  10%|████▍                                       | 1/10 [00:14<02:12, 14.73s/it]Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/1.jpg en 2.1 seconds.
#  20%|████████▊                                   | 2/10 [00:16<00:58,  7.31s/it]2022-06-30 12:08:12.926788: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/9.jpg en 4.36 seconds.
#  30%|█████████████▏                              | 3/10 [00:21<00:41,  5.97s/it]2022-06-30 12:08:15.266012: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.07GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-06-30 12:08:17.735354: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/6.jpg en 4.9 seconds.
#  40%|█████████████████▌                          | 4/10 [00:26<00:33,  5.55s/it]2022-06-30 12:08:22.357427: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/2.jpg en 4.56 seconds.
#  50%|██████████████████████                      | 5/10 [00:30<00:25,  5.19s/it]2022-06-30 12:08:27.096672: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/5.jpeg en 4.76 seconds.
#  60%|██████████████████████████▍                 | 6/10 [00:35<00:20,  5.05s/it]2022-06-30 12:08:31.645527: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/10.jpg en 4.58 seconds.
#  70%|██████████████████████████████▊             | 7/10 [00:40<00:14,  4.89s/it]Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/8.jpg en 2.17 seconds.
#  80%|███████████████████████████████████▏        | 8/10 [00:42<00:08,  4.03s/it]2022-06-30 12:08:38.474317: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/4.jpeg en 4.71 seconds.
#  90%|███████████████████████████████████████▌    | 9/10 [00:46<00:04,  4.24s/it]Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/7.jpg en 2.46 seconds.
# 100%|███████████████████████████████████████████| 10/10 [00:49<00:00,  4.94s/it]
# ==========================================================================================
# Fichero de salida guardado en /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/output_json/2022-06-30_10-08.json
# ==========================================================================================
# ==========================================================================================
# De media, por cada imagen,
# Ha tomado 0.01 seconds en cargar, con desviación de 0.01 seconds
# Ha tomado 4.93 seconds en procesar, con desviación de 3.63 seconds
# ==========================================================================================
# ==========================================================================================
