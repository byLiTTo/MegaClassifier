# %%
import os
import platform

#########################################################################################################################################################
# PARAMETROS DEFINIDOS EN FUNCION DEL USUARIO
#########################################################################################################################################################

# Ruta relativa hacia la librería ai4eutils
ai4eutils_relative = "./repos/ai4eutils"

# Ruta relativa hacia la librería CameraTraps
CameraTraps_relative = "./repos/CameraTraps"

# Ruta relativa hacia carpeta de imagenes de entrada
images_dir_relative = './input'

# Ruta relativa hacia la carpeta destino de los ficheros JSON:
output_json_path_relative = ('./output_json')

# Ruta relativa al modelo de detección
model_relative = './models/megadetector_v4_1_0.pb'

#########################################################################################################################################################
#########################################################################################################################################################

home = os.path.expanduser("~")

ai4utils = os.path.abspath(ai4eutils_relative)
CameraTraps = os.path.abspath(CameraTraps_relative)
images_dir = os.path.abspath(images_dir_relative)
output_json = os.path.abspath(output_json_path_relative)
model = os.path.abspath(model_relative)

try:
    os.environ['PYTHONPATH']
except KeyError:
    os.environ['PYTHONPATH'] = ""
if platform.system() == 'Windows':
    os.environ['PYTHONPATH'] += (";" + ai4utils)
    os.environ['PYTHONPATH'] += (";" + CameraTraps)
else:
    os.environ['PYTHONPATH'] += (":" + ai4utils)
    os.environ['PYTHONPATH'] += (":" + CameraTraps)

print('=======================================================================================================================================')
print('PYTHONPATH: ' + os.environ['PYTHONPATH'])
print('')
print('ai4eutils PATH: ' + '\t' + ai4utils)
print('CameraTraps PATH: ' + '\t' + CameraTraps)
print('input PATH: ' + '\t' + '\t' + images_dir)
print('output_json PATH: ' + '\t' + output_json)
print('modelo: ' + '\t' + '\t' + model)
print('=======================================================================================================================================')
# Out:
# =======================================================================================================================================
# PYTHONPATH: /home/carlos/.vscode/extensions/ms-toolsai.jupyter-2022.6.1101950301/pythonFiles:/home/carlos/.vscode/extensions/ms-toolsai.jupyter-2022.6.1101950301/pythonFiles/lib/python:/home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/ai4eutils:/home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/CameraTraps
#
# ai4eutils PATH: 	/home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/ai4eutils
# CameraTraps PATH: 	/home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/repos/CameraTraps
# input PATH: 		/home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input
# output_json PATH: 	/home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/output_json
# modelo: 		/home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/models/megadetector_v4_1_0.pb
# =======================================================================================================================================

# %%
# !python ./modules/genera_detecciones.py "$model" --image_dir "$images_dir" --output_dir "$output_json"
# Out:
# 2022-07-12 17:33:35.127026: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
# ==========================================================================================
# TensorFlow version: 2.4.1
# 2022-07-12 17:33:36.006334: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-07-12 17:33:36.006927: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-07-12 17:33:36.042213: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 17:33:36.042780: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1050 Ti with Max-Q Design computeCapability: 6.1
# coreClock: 1.2905GHz coreCount: 6 deviceMemorySize: 3.95GiB deviceMemoryBandwidth: 104.43GiB/s
# 2022-07-12 17:33:36.042810: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-07-12 17:33:36.044570: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-07-12 17:33:36.044617: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-07-12 17:33:36.046021: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-07-12 17:33:36.046264: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-07-12 17:33:36.047858: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-07-12 17:33:36.048752: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-07-12 17:33:36.052286: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-07-12 17:33:36.052529: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 17:33:36.053201: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 17:33:36.053600: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# Is GPU available? tf.test.is_gpu_available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ==========================================================================================
#
# Ejecutando detector en 10 imágenes...
#
# ==========================================================================================
# TFDetector: Cargando gráficos
# TFDetector: Gráficos de detección, cargados.
# ==========================================================================================
#
# 2022-07-12 17:33:40.943293: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-12 17:33:40.944123: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-07-12 17:33:40.944237: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 17:33:40.944592: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1050 Ti with Max-Q Design computeCapability: 6.1
# coreClock: 1.2905GHz coreCount: 6 deviceMemorySize: 3.95GiB deviceMemoryBandwidth: 104.43GiB/s
# 2022-07-12 17:33:40.944619: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-07-12 17:33:40.944636: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-07-12 17:33:40.944647: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-07-12 17:33:40.944657: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-07-12 17:33:40.944667: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-07-12 17:33:40.944676: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-07-12 17:33:40.944685: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-07-12 17:33:40.944695: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-07-12 17:33:40.944739: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 17:33:40.945077: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 17:33:40.945400: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-07-12 17:33:40.945427: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-07-12 17:33:41.249109: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-07-12 17:33:41.249145: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-07-12 17:33:41.249152: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-07-12 17:33:41.249317: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 17:33:41.249706: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 17:33:41.250077: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 17:33:41.250296: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 3500 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1050 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 6.1)
#
# Modelo cargado en: 5.2 seconds.
# ==========================================================================================
#
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
# 2022-07-12 17:33:41.673310: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:196] None of the MLIR optimization passes are enabled (registered 0 passes)
# 2022-07-12 17:33:41.873855: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2199995000 Hz
# 2022-07-12 17:33:47.748181: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-07-12 17:33:47.869982: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-07-12 17:33:51.057112: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
#
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/3.jpg en 14.16 seconds.
#  10%|████▍                                       | 1/10 [00:14<02:07, 14.17s/it]
#
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/1.jpg en 1.9 seconds.
#  20%|████████▊                                   | 2/10 [00:16<00:55,  6.96s/it]
# 2022-07-12 17:34:00.042037: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
#
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/9.jpg en 4.09 seconds.
#  30%|█████████████▏                              | 3/10 [00:20<00:39,  5.65s/it]
# 2022-07-12 17:34:02.241862: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.07GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-07-12 17:34:04.516894: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
#
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/6.jpg en 4.51 seconds.
#  40%|█████████████████▌                          | 4/10 [00:24<00:31,  5.21s/it]
# 2022-07-12 17:34:08.609161: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
#
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/2.jpg en 4 seconds.
#  50%|██████████████████████                      | 5/10 [00:28<00:23,  4.77s/it]
# 2022-07-12 17:34:12.823522: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
#
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/5.jpeg en 4.27 seconds.
#  60%|██████████████████████████▍                 | 6/10 [00:32<00:18,  4.60s/it]
# 2022-07-12 17:34:16.909591: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
#
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/10.jpg en 4.01 seconds.
#  70%|██████████████████████████████▊             | 7/10 [00:36<00:13,  4.41s/it]
#
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/8.jpg en 1.88 seconds.
#  80%|███████████████████████████████████▏        | 8/10 [00:38<00:07,  3.61s/it]
# 2022-07-12 17:34:22.884238: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
#
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/4.jpeg en 4.14 seconds.
#  90%|███████████████████████████████████████▌    | 9/10 [00:43<00:03,  3.77s/it]
#
# Generadas detecciones de imagen /home/carlos/WORKSPACE/TFG-DeteccionFototrampeo/input/7.jpg en 2.11 seconds.
# 100%|███████████████████████████████████████████| 10/10 [00:45<00:00,  4.51s/it]
#
# ==========================================================================================
# Generado JSON con detecciones
# ==========================================================================================
#
# ==========================================================================================
# De media, por cada imagen,
# Ha tomado 0.01 seconds en cargar, con desviación de 0.01 seconds
# Ha tomado 4.51 seconds en procesar, con desviación de 3.55 seconds
# ==========================================================================================
#
# ==========================================================================================
